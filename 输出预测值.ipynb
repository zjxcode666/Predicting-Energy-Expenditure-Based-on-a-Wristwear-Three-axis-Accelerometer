# %%
import numpy as np
import pandas as pd
import os
import csv
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_squared_error as MSE
import time

# %%
freq=60
file_path = './训练集与测试集数据'
train_data_path = os.path.join(file_path, 'train_data_{0}.csv'.format(str(freq)))
val_data_path= os.path.join(file_path, 'val_data_{0}.csv'.format(str(freq)))
train_data_pd = pd.read_csv(train_data_path,encoding="gbk")
val_data_pd = pd.read_csv(val_data_path,encoding="gbk")
print (train_data_pd)
# Out:
#       name       MET  speed    mean      sd     min     max    10th    25th  \
# 0      乔金英  4.500000      2  1.0105  0.0967  0.7925  1.4301  0.9032  0.9364
# 1      乔金英  4.166667      2  1.0129  0.1036  0.7152  1.3600  0.8969  0.9312
# 2      乔金英  4.466667      3  1.0591  0.1641  0.6688  1.6669  0.8532  0.9365
# 3      乔金英  4.483333      3  1.0750  0.1790  0.6608  1.7861  0.8534  0.9394
# 4      乔金英  4.733333      4  1.0848  0.1637  0.6237  1.5906  0.8840  0.9673
# ...    ...       ...    ...     ...     ...     ...     ...     ...     ...
# 1115  龚兴广2  6.616667      7  1.2954  0.7956  0.1243  3.1906  0.5234  0.6684
# 1116  龚兴广2  7.300000      8  1.3821  0.8335  0.1893  3.7131  0.5939  0.7397
# 1117  龚兴广2  7.333333      8  1.3745  0.8195  0.1815  3.4649  0.5819  0.7517
# 1118  龚兴广2  7.950000      9  1.4035  0.8506  0.1862  3.6185  0.6063  0.7583
# 1119  龚兴广2  8.216667      9  1.4131  0.8380  0.0960  3.7785  0.6038  0.7969
#
#         50th    75th    90th
# 0     0.9874  1.0817  1.1494
# 1     0.9894  1.0876  1.1638
# 2     1.0407  1.1861  1.2911
# 3     1.0576  1.2082  1.3267
# 4     1.0627  1.2089  1.3154
# ...      ...     ...     ...
# 1115  0.9646  1.8988  2.6334
# 1116  1.0532  2.0101  2.8121
# 1117  1.0558  1.9895  2.7801
# 1118  1.0644  1.9519  2.8605
# 1119  1.0925  1.9455  2.8253
#
# [1120 rows x 12 columns]

# %%
X_train = train_data_pd[['mean', 'sd', 'min', 'max', '10th', '25th', '50th', '75th','90th']]
Y_train = train_data_pd[['MET']]
X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_val = val_data_pd[['mean',  'sd', 'min', 'max', '10th', '25th', '50th', '75th','90th']]
Y_val = val_data_pd[['MET']]
X_val = np.array(X_val)
Y_val = np.array(Y_val)
print(X_train)
# Out:
# [[1.0105 0.0967 0.7925 ... 0.9874 1.0817 1.1494]
#  [1.0129 0.1036 0.7152 ... 0.9894 1.0876 1.1638]
#  [1.0591 0.1641 0.6688 ... 1.0407 1.1861 1.2911]
#  ...
#  [1.3745 0.8195 0.1815 ... 1.0558 1.9895 2.7801]
#  [1.4035 0.8506 0.1862 ... 1.0644 1.9519 2.8605]
#  [1.4131 0.838  0.096  ... 1.0925 1.9455 2.8253]]

# %%
scaler = MinMaxScaler()
X_all = np.concatenate([X_train, X_val], axis=0)
scaler = scaler.fit(X_all)

# %%
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)

# %%
import torch
import torch.nn as nn

# %%
X_train_tensor = torch.from_numpy(X_train).float() 
Y_train_tensor = torch.from_numpy(Y_train).float()

# %%
X_val_tensor = torch.from_numpy(X_val).float() 
Y_val_tensor = torch.from_numpy(Y_val).float()

# %%
d1=9 
d2=8
d3=1
#d4=1
class Network(torch.nn.Module):
    def __init__(self): 
        super(Network,self).__init__()
        self.fc1 = nn.Linear(d1, d2) 
        self.fc2 = nn.Linear(d2, d3)
    def forward(self,x): 
        out = self.fc1(x)
        out = self.fc2(out)
        return out

# %%
def init_weights(layer):
    if type(layer) == nn.Conv2d:
        nn.init.normal_(layer.weight, mean=0, std=0.5)
    elif type(layer) == nn.Linear:
        nn.init.uniform_(layer.weight, a=-0.1, b=0.1)
        nn.init.constant_(layer.bias, 0.1)

# %%
torch.manual_seed(2021)

# %%
net = Network()
net.apply(init_weights)
criterion = torch.nn.MSELoss() 
optimizer = torch.optim.SGD(net.parameters(), 0.01, momentum=0.8)
nums_epochs = 2000   
loss_data_train = []
loss_data_val = []
for i in range(nums_epochs): 
    train_data = X_train_tensor.unsqueeze(1)   
    target_data = Y_train_tensor.unsqueeze(1) 
    output_predict = net(train_data)  
    data_loss = criterion(output_predict,target_data) 
    loss_data_train.append(data_loss.item())
    optimizer.zero_grad()               
    data_loss.backward()                 
    optimizer.step()                    
    print("Epoch:[{}/{}],data_loss:[{:.4f}]".format(i+1,nums_epochs,data_loss.item()))
    if i % 20 == 0:
        val_data = X_val_tensor.unsqueeze(1)
        val_target = Y_val_tensor.unsqueeze(1)
        output_predict = net(val_data) 
        data_loss = criterion(output_predict,val_target)
        loss_data_val.append(data_loss.item())
# Out:
# Epoch:[1/2000],data_loss:[41.1338]
# Epoch:[2/2000],data_loss:[39.5671]
# Epoch:[3/2000],data_loss:[36.8144]
# Epoch:[4/2000],data_loss:[33.1716]
# Epoch:[5/2000],data_loss:[28.8068]
# Epoch:[6/2000],data_loss:[23.7814]
# Epoch:[7/2000],data_loss:[18.1623]
# Epoch:[8/2000],data_loss:[12.2780]
# Epoch:[9/2000],data_loss:[7.0922]
# Epoch:[10/2000],data_loss:[4.2422]
# Epoch:[11/2000],data_loss:[4.7475]
# Epoch:[12/2000],data_loss:[6.8882]
# Epoch:[13/2000],data_loss:[7.3288]
# Epoch:[14/2000],data_loss:[5.4844]
# Epoch:[15/2000],data_loss:[3.4787]
# Epoch:[16/2000],data_loss:[2.6060]
# Epoch:[17/2000],data_loss:[2.5959]
# Epoch:[18/2000],data_loss:[2.7851]
# Epoch:[19/2000],data_loss:[2.7764]
# Epoch:[20/2000],data_loss:[2.4810]
# Epoch:[21/2000],data_loss:[2.0028]
# Epoch:[22/2000],data_loss:[1.5283]
# Epoch:[23/2000],data_loss:[1.2201]
# Epoch:[24/2000],data_loss:[1.1225]
# Epoch:[25/2000],data_loss:[1.1419]
# Epoch:[26/2000],data_loss:[1.1399]
# Epoch:[27/2000],data_loss:[1.0568]
# Epoch:[28/2000],data_loss:[0.9376]
# Epoch:[29/2000],data_loss:[0.8548]
# Epoch:[30/2000],data_loss:[0.8361]
# Epoch:[31/2000],data_loss:[0.8582]
# Epoch:[32/2000],data_loss:[0.8824]
# Epoch:[33/2000],data_loss:[0.8864]
# Epoch:[34/2000],data_loss:[0.8719]
# Epoch:[35/2000],data_loss:[0.8538]
# Epoch:[36/2000],data_loss:[0.8449]
# Epoch:[37/2000],data_loss:[0.8465]
# Epoch:[38/2000],data_loss:[0.8514]
# Epoch:[39/2000],data_loss:[0.8520]
# Epoch:[40/2000],data_loss:[0.8467]
# Epoch:[41/2000],data_loss:[0.8390]
# Epoch:[42/2000],data_loss:[0.8332]
# Epoch:[43/2000],data_loss:[0.8309]
# Epoch:[44/2000],data_loss:[0.8308]
# Epoch:[45/2000],data_loss:[0.8307]
# Epoch:[46/2000],data_loss:[0.8297]
# Epoch:[47/2000],data_loss:[0.8280]
# Epoch:[48/2000],data_loss:[0.8264]
# Epoch:[49/2000],data_loss:[0.8256]
# Epoch:[50/2000],data_loss:[0.8254]
# Epoch:[51/2000],data_loss:[0.8255]
# Epoch:[52/2000],data_loss:[0.8253]
# Epoch:[53/2000],data_loss:[0.8248]
# Epoch:[54/2000],data_loss:[0.8242]
# Epoch:[55/2000],data_loss:[0.8236]
# Epoch:[56/2000],data_loss:[0.8233]
# Epoch:[57/2000],data_loss:[0.8229]
# Epoch:[58/2000],data_loss:[0.8226]
# Epoch:[59/2000],data_loss:[0.8222]
# Epoch:[60/2000],data_loss:[0.8218]
# Epoch:[61/2000],data_loss:[0.8214]
# Epoch:[62/2000],data_loss:[0.8210]
# Epoch:[63/2000],data_loss:[0.8207]
# Epoch:[64/2000],data_loss:[0.8203]
# Epoch:[65/2000],data_loss:[0.8200]
# Epoch:[66/2000],data_loss:[0.8197]
# Epoch:[67/2000],data_loss:[0.8193]
# Epoch:[68/2000],data_loss:[0.8190]
# Epoch:[69/2000],data_loss:[0.8187]
# Epoch:[70/2000],data_loss:[0.8184]
# Epoch:[71/2000],data_loss:[0.8181]
# Epoch:[72/2000],data_loss:[0.8177]
# Epoch:[73/2000],data_loss:[0.8174]
# Epoch:[74/2000],data_loss:[0.8171]
# Epoch:[75/2000],data_loss:[0.8168]
# Epoch:[76/2000],data_loss:[0.8165]
# Epoch:[77/2000],data_loss:[0.8162]
# Epoch:[78/2000],data_loss:[0.8159]
# Epoch:[79/2000],data_loss:[0.8156]
# Epoch:[80/2000],data_loss:[0.8153]
# Epoch:[81/2000],data_loss:[0.8150]
# Epoch:[82/2000],data_loss:[0.8147]
# Epoch:[83/2000],data_loss:[0.8144]
# Epoch:[84/2000],data_loss:[0.8141]
# Epoch:[85/2000],data_loss:[0.8138]
# Epoch:[86/2000],data_loss:[0.8136]
# Epoch:[87/2000],data_loss:[0.8133]
# Epoch:[88/2000],data_loss:[0.8130]
# Epoch:[89/2000],data_loss:[0.8127]
# Epoch:[90/2000],data_loss:[0.8124]
# Epoch:[91/2000],data_loss:[0.8122]
# Epoch:[92/2000],data_loss:[0.8119]
# Epoch:[93/2000],data_loss:[0.8116]
# Epoch:[94/2000],data_loss:[0.8113]
# Epoch:[95/2000],data_loss:[0.8111]
# Epoch:[96/2000],data_loss:[0.8108]
# Epoch:[97/2000],data_loss:[0.8105]
# Epoch:[98/2000],data_loss:[0.8103]
# Epoch:[99/2000],data_loss:[0.8100]
# Epoch:[100/2000],data_loss:[0.8097]
# Epoch:[101/2000],data_loss:[0.8095]
# Epoch:[102/2000],data_loss:[0.8092]
# Epoch:[103/2000],data_loss:[0.8090]
# Epoch:[104/2000],data_loss:[0.8087]
# Epoch:[105/2000],data_loss:[0.8084]
# Epoch:[106/2000],data_loss:[0.8082]
# Epoch:[107/2000],data_loss:[0.8079]
# Epoch:[108/2000],data_loss:[0.8077]
# Epoch:[109/2000],data_loss:[0.8074]
# Epoch:[110/2000],data_loss:[0.8072]
# Epoch:[111/2000],data_loss:[0.8069]
# Epoch:[112/2000],data_loss:[0.8067]
# Epoch:[113/2000],data_loss:[0.8064]
# Epoch:[114/2000],data_loss:[0.8062]
# Epoch:[115/2000],data_loss:[0.8060]
# Epoch:[116/2000],data_loss:[0.8057]
# Epoch:[117/2000],data_loss:[0.8055]
# Epoch:[118/2000],data_loss:[0.8052]
# Epoch:[119/2000],data_loss:[0.8050]
# Epoch:[120/2000],data_loss:[0.8048]
# Epoch:[121/2000],data_loss:[0.8045]
# Epoch:[122/2000],data_loss:[0.8043]
# Epoch:[123/2000],data_loss:[0.8041]
# Epoch:[124/2000],data_loss:[0.8038]
# Epoch:[125/2000],data_loss:[0.8036]
# Epoch:[126/2000],data_loss:[0.8034]
# Epoch:[127/2000],data_loss:[0.8031]
# Epoch:[128/2000],data_loss:[0.8029]
# Epoch:[129/2000],data_loss:[0.8027]
# Epoch:[130/2000],data_loss:[0.8025]
# Epoch:[131/2000],data_loss:[0.8022]
# Epoch:[132/2000],data_loss:[0.8020]
# Epoch:[133/2000],data_loss:[0.8018]
# Epoch:[134/2000],data_loss:[0.8016]
# Epoch:[135/2000],data_loss:[0.8014]
# Epoch:[136/2000],data_loss:[0.8011]
# Epoch:[137/2000],data_loss:[0.8009]
# Epoch:[138/2000],data_loss:[0.8007]
# Epoch:[139/2000],data_loss:[0.8005]
# Epoch:[140/2000],data_loss:[0.8003]
# Epoch:[141/2000],data_loss:[0.8000]
# Epoch:[142/2000],data_loss:[0.7998]
# Epoch:[143/2000],data_loss:[0.7996]
# Epoch:[144/2000],data_loss:[0.7994]
# Epoch:[145/2000],data_loss:[0.7992]
# Epoch:[146/2000],data_loss:[0.7990]
# Epoch:[147/2000],data_loss:[0.7988]
# Epoch:[148/2000],data_loss:[0.7986]
# Epoch:[149/2000],data_loss:[0.7984]
# Epoch:[150/2000],data_loss:[0.7982]
# Epoch:[151/2000],data_loss:[0.7980]
# Epoch:[152/2000],data_loss:[0.7978]
# Epoch:[153/2000],data_loss:[0.7975]
# Epoch:[154/2000],data_loss:[0.7973]
# Epoch:[155/2000],data_loss:[0.7971]
# Epoch:[156/2000],data_loss:[0.7969]
# Epoch:[157/2000],data_loss:[0.7967]
# Epoch:[158/2000],data_loss:[0.7965]
# Epoch:[159/2000],data_loss:[0.7963]
# Epoch:[160/2000],data_loss:[0.7961]
# Epoch:[161/2000],data_loss:[0.7959]
# Epoch:[162/2000],data_loss:[0.7958]
# Epoch:[163/2000],data_loss:[0.7956]
# Epoch:[164/2000],data_loss:[0.7954]
# Epoch:[165/2000],data_loss:[0.7952]
# Epoch:[166/2000],data_loss:[0.7950]
# Epoch:[167/2000],data_loss:[0.7948]
# Epoch:[168/2000],data_loss:[0.7946]
# Epoch:[169/2000],data_loss:[0.7944]
# Epoch:[170/2000],data_loss:[0.7942]
# Epoch:[171/2000],data_loss:[0.7940]
# Epoch:[172/2000],data_loss:[0.7938]
# Epoch:[173/2000],data_loss:[0.7936]
# Epoch:[174/2000],data_loss:[0.7935]
# Epoch:[175/2000],data_loss:[0.7933]
# Epoch:[176/2000],data_loss:[0.7931]
# Epoch:[177/2000],data_loss:[0.7929]
# Epoch:[178/2000],data_loss:[0.7927]
# Epoch:[179/2000],data_loss:[0.7925]
# Epoch:[180/2000],data_loss:[0.7924]
# Epoch:[181/2000],data_loss:[0.7922]
# Epoch:[182/2000],data_loss:[0.7920]
# Epoch:[183/2000],data_loss:[0.7918]
# Epoch:[184/2000],data_loss:[0.7916]
# Epoch:[185/2000],data_loss:[0.7915]
# Epoch:[186/2000],data_loss:[0.7913]
# Epoch:[187/2000],data_loss:[0.7911]
# Epoch:[188/2000],data_loss:[0.7909]
# Epoch:[189/2000],data_loss:[0.7907]
# Epoch:[190/2000],data_loss:[0.7906]
# Epoch:[191/2000],data_loss:[0.7904]
# Epoch:[192/2000],data_loss:[0.7902]
# Epoch:[193/2000],data_loss:[0.7900]
# Epoch:[194/2000],data_loss:[0.7899]
# Epoch:[195/2000],data_loss:[0.7897]
# Epoch:[196/2000],data_loss:[0.7895]
# Epoch:[197/2000],data_loss:[0.7894]
# Epoch:[198/2000],data_loss:[0.7892]
# Epoch:[199/2000],data_loss:[0.7890]
# Epoch:[200/2000],data_loss:[0.7888]
# Epoch:[201/2000],data_loss:[0.7887]
# Epoch:[202/2000],data_loss:[0.7885]
# Epoch:[203/2000],data_loss:[0.7883]
# Epoch:[204/2000],data_loss:[0.7882]
# Epoch:[205/2000],data_loss:[0.7880]
# Epoch:[206/2000],data_loss:[0.7878]
# Epoch:[207/2000],data_loss:[0.7877]
# Epoch:[208/2000],data_loss:[0.7875]
# Epoch:[209/2000],data_loss:[0.7874]
# Epoch:[210/2000],data_loss:[0.7872]
# Epoch:[211/2000],data_loss:[0.7870]
# Epoch:[212/2000],data_loss:[0.7869]
# Epoch:[213/2000],data_loss:[0.7867]
# Epoch:[214/2000],data_loss:[0.7866]
# Epoch:[215/2000],data_loss:[0.7864]
# Epoch:[216/2000],data_loss:[0.7862]
# Epoch:[217/2000],data_loss:[0.7861]
# Epoch:[218/2000],data_loss:[0.7859]
# Epoch:[219/2000],data_loss:[0.7858]
# Epoch:[220/2000],data_loss:[0.7856]
# Epoch:[221/2000],data_loss:[0.7854]
# Epoch:[222/2000],data_loss:[0.7853]
# Epoch:[223/2000],data_loss:[0.7851]
# Epoch:[224/2000],data_loss:[0.7850]
# Epoch:[225/2000],data_loss:[0.7848]
# Epoch:[226/2000],data_loss:[0.7847]
# Epoch:[227/2000],data_loss:[0.7845]
# Epoch:[228/2000],data_loss:[0.7844]
# Epoch:[229/2000],data_loss:[0.7842]
# Epoch:[230/2000],data_loss:[0.7841]
# Epoch:[231/2000],data_loss:[0.7839]
# Epoch:[232/2000],data_loss:[0.7838]
# Epoch:[233/2000],data_loss:[0.7836]
# Epoch:[234/2000],data_loss:[0.7835]
# Epoch:[235/2000],data_loss:[0.7833]
# Epoch:[236/2000],data_loss:[0.7832]
# Epoch:[237/2000],data_loss:[0.7830]
# Epoch:[238/2000],data_loss:[0.7829]
# Epoch:[239/2000],data_loss:[0.7827]
# Epoch:[240/2000],data_loss:[0.7826]
# Epoch:[241/2000],data_loss:[0.7824]
# Epoch:[242/2000],data_loss:[0.7823]
# Epoch:[243/2000],data_loss:[0.7822]
# Epoch:[244/2000],data_loss:[0.7820]
# Epoch:[245/2000],data_loss:[0.7819]
# Epoch:[246/2000],data_loss:[0.7817]
# Epoch:[247/2000],data_loss:[0.7816]
# Epoch:[248/2000],data_loss:[0.7814]
# Epoch:[249/2000],data_loss:[0.7813]
# Epoch:[250/2000],data_loss:[0.7812]
# Epoch:[251/2000],data_loss:[0.7810]
# Epoch:[252/2000],data_loss:[0.7809]
# Epoch:[253/2000],data_loss:[0.7807]
# Epoch:[254/2000],data_loss:[0.7806]
# Epoch:[255/2000],data_loss:[0.7805]
# Epoch:[256/2000],data_loss:[0.7803]
# Epoch:[257/2000],data_loss:[0.7802]
# Epoch:[258/2000],data_loss:[0.7801]
# Epoch:[259/2000],data_loss:[0.7799]
# Epoch:[260/2000],data_loss:[0.7798]
# Epoch:[261/2000],data_loss:[0.7796]
# Epoch:[262/2000],data_loss:[0.7795]
# Epoch:[263/2000],data_loss:[0.7794]
# Epoch:[264/2000],data_loss:[0.7792]
# Epoch:[265/2000],data_loss:[0.7791]
# Epoch:[266/2000],data_loss:[0.7790]
# Epoch:[267/2000],data_loss:[0.7788]
# Epoch:[268/2000],data_loss:[0.7787]
# Epoch:[269/2000],data_loss:[0.7786]
# Epoch:[270/2000],data_loss:[0.7785]
# Epoch:[271/2000],data_loss:[0.7783]
# Epoch:[272/2000],data_loss:[0.7782]
# Epoch:[273/2000],data_loss:[0.7781]
# Epoch:[274/2000],data_loss:[0.7779]
# Epoch:[275/2000],data_loss:[0.7778]
# Epoch:[276/2000],data_loss:[0.7777]
# Epoch:[277/2000],data_loss:[0.7776]
# Epoch:[278/2000],data_loss:[0.7774]
# Epoch:[279/2000],data_loss:[0.7773]
# Epoch:[280/2000],data_loss:[0.7772]
# Epoch:[281/2000],data_loss:[0.7770]
# Epoch:[282/2000],data_loss:[0.7769]
# Epoch:[283/2000],data_loss:[0.7768]
# Epoch:[284/2000],data_loss:[0.7767]
# Epoch:[285/2000],data_loss:[0.7766]
# Epoch:[286/2000],data_loss:[0.7764]
# Epoch:[287/2000],data_loss:[0.7763]
# Epoch:[288/2000],data_loss:[0.7762]
# Epoch:[289/2000],data_loss:[0.7761]
# Epoch:[290/2000],data_loss:[0.7759]
# Epoch:[291/2000],data_loss:[0.7758]
# Epoch:[292/2000],data_loss:[0.7757]
# Epoch:[293/2000],data_loss:[0.7756]
# Epoch:[294/2000],data_loss:[0.7755]
# Epoch:[295/2000],data_loss:[0.7753]
# Epoch:[296/2000],data_loss:[0.7752]
# Epoch:[297/2000],data_loss:[0.7751]
# Epoch:[298/2000],data_loss:[0.7750]
# Epoch:[299/2000],data_loss:[0.7749]
# Epoch:[300/2000],data_loss:[0.7747]
# Epoch:[301/2000],data_loss:[0.7746]
# Epoch:[302/2000],data_loss:[0.7745]
# Epoch:[303/2000],data_loss:[0.7744]
# Epoch:[304/2000],data_loss:[0.7743]
# Epoch:[305/2000],data_loss:[0.7742]
# Epoch:[306/2000],data_loss:[0.7741]
# Epoch:[307/2000],data_loss:[0.7739]
# Epoch:[308/2000],data_loss:[0.7738]
# Epoch:[309/2000],data_loss:[0.7737]
# Epoch:[310/2000],data_loss:[0.7736]
# Epoch:[311/2000],data_loss:[0.7735]
# Epoch:[312/2000],data_loss:[0.7734]
# Epoch:[313/2000],data_loss:[0.7733]
# Epoch:[314/2000],data_loss:[0.7731]
# Epoch:[315/2000],data_loss:[0.7730]
# Epoch:[316/2000],data_loss:[0.7729]
# Epoch:[317/2000],data_loss:[0.7728]
# Epoch:[318/2000],data_loss:[0.7727]
# Epoch:[319/2000],data_loss:[0.7726]
# Epoch:[320/2000],data_loss:[0.7725]
# Epoch:[321/2000],data_loss:[0.7724]
# Epoch:[322/2000],data_loss:[0.7723]
# Epoch:[323/2000],data_loss:[0.7722]
# Epoch:[324/2000],data_loss:[0.7721]
# Epoch:[325/2000],data_loss:[0.7719]
# Epoch:[326/2000],data_loss:[0.7718]
# Epoch:[327/2000],data_loss:[0.7717]
# Epoch:[328/2000],data_loss:[0.7716]
# Epoch:[329/2000],data_loss:[0.7715]
# Epoch:[330/2000],data_loss:[0.7714]
# Epoch:[331/2000],data_loss:[0.7713]
# Epoch:[332/2000],data_loss:[0.7712]
# Epoch:[333/2000],data_loss:[0.7711]
# Epoch:[334/2000],data_loss:[0.7710]
# Epoch:[335/2000],data_loss:[0.7709]
# Epoch:[336/2000],data_loss:[0.7708]
# Epoch:[337/2000],data_loss:[0.7707]
# Epoch:[338/2000],data_loss:[0.7706]
# Epoch:[339/2000],data_loss:[0.7705]
# Epoch:[340/2000],data_loss:[0.7704]
# Epoch:[341/2000],data_loss:[0.7703]
# Epoch:[342/2000],data_loss:[0.7702]
# Epoch:[343/2000],data_loss:[0.7701]
# Epoch:[344/2000],data_loss:[0.7700]
# Epoch:[345/2000],data_loss:[0.7699]
# Epoch:[346/2000],data_loss:[0.7698]
# Epoch:[347/2000],data_loss:[0.7697]
# Epoch:[348/2000],data_loss:[0.7696]
# Epoch:[349/2000],data_loss:[0.7695]
# Epoch:[350/2000],data_loss:[0.7694]
# Epoch:[351/2000],data_loss:[0.7693]
# Epoch:[352/2000],data_loss:[0.7692]
# Epoch:[353/2000],data_loss:[0.7691]
# Epoch:[354/2000],data_loss:[0.7690]
# Epoch:[355/2000],data_loss:[0.7689]
# Epoch:[356/2000],data_loss:[0.7688]
# Epoch:[357/2000],data_loss:[0.7687]
# Epoch:[358/2000],data_loss:[0.7686]
# Epoch:[359/2000],data_loss:[0.7685]
# Epoch:[360/2000],data_loss:[0.7684]
# Epoch:[361/2000],data_loss:[0.7683]
# Epoch:[362/2000],data_loss:[0.7682]
# Epoch:[363/2000],data_loss:[0.7681]
# Epoch:[364/2000],data_loss:[0.7681]
# Epoch:[365/2000],data_loss:[0.7680]
# Epoch:[366/2000],data_loss:[0.7679]
# Epoch:[367/2000],data_loss:[0.7678]
# Epoch:[368/2000],data_loss:[0.7677]
# Epoch:[369/2000],data_loss:[0.7676]
# Epoch:[370/2000],data_loss:[0.7675]
# Epoch:[371/2000],data_loss:[0.7674]
# Epoch:[372/2000],data_loss:[0.7673]
# Epoch:[373/2000],data_loss:[0.7672]
# Epoch:[374/2000],data_loss:[0.7671]
# Epoch:[375/2000],data_loss:[0.7671]
# Epoch:[376/2000],data_loss:[0.7670]
# Epoch:[377/2000],data_loss:[0.7669]
# Epoch:[378/2000],data_loss:[0.7668]
# Epoch:[379/2000],data_loss:[0.7667]
# Epoch:[380/2000],data_loss:[0.7666]
# Epoch:[381/2000],data_loss:[0.7665]
# Epoch:[382/2000],data_loss:[0.7664]
# Epoch:[383/2000],data_loss:[0.7663]
# Epoch:[384/2000],data_loss:[0.7663]
# Epoch:[385/2000],data_loss:[0.7662]
# Epoch:[386/2000],data_loss:[0.7661]
# Epoch:[387/2000],data_loss:[0.7660]
# Epoch:[388/2000],data_loss:[0.7659]
# Epoch:[389/2000],data_loss:[0.7658]
# Epoch:[390/2000],data_loss:[0.7657]
# Epoch:[391/2000],data_loss:[0.7657]
# Epoch:[392/2000],data_loss:[0.7656]
# Epoch:[393/2000],data_loss:[0.7655]
# Epoch:[394/2000],data_loss:[0.7654]
# Epoch:[395/2000],data_loss:[0.7653]
# Epoch:[396/2000],data_loss:[0.7652]
# Epoch:[397/2000],data_loss:[0.7652]
# Epoch:[398/2000],data_loss:[0.7651]
# Epoch:[399/2000],data_loss:[0.7650]
# Epoch:[400/2000],data_loss:[0.7649]
# Epoch:[401/2000],data_loss:[0.7648]
# Epoch:[402/2000],data_loss:[0.7648]
# Epoch:[403/2000],data_loss:[0.7647]
# Epoch:[404/2000],data_loss:[0.7646]
# Epoch:[405/2000],data_loss:[0.7645]
# Epoch:[406/2000],data_loss:[0.7644]
# Epoch:[407/2000],data_loss:[0.7644]
# Epoch:[408/2000],data_loss:[0.7643]
# Epoch:[409/2000],data_loss:[0.7642]
# Epoch:[410/2000],data_loss:[0.7641]
# Epoch:[411/2000],data_loss:[0.7640]
# Epoch:[412/2000],data_loss:[0.7640]
# Epoch:[413/2000],data_loss:[0.7639]
# Epoch:[414/2000],data_loss:[0.7638]
# Epoch:[415/2000],data_loss:[0.7637]
# Epoch:[416/2000],data_loss:[0.7636]
# Epoch:[417/2000],data_loss:[0.7636]
# Epoch:[418/2000],data_loss:[0.7635]
# Epoch:[419/2000],data_loss:[0.7634]
# Epoch:[420/2000],data_loss:[0.7633]
# Epoch:[421/2000],data_loss:[0.7633]
# Epoch:[422/2000],data_loss:[0.7632]
# Epoch:[423/2000],data_loss:[0.7631]
# Epoch:[424/2000],data_loss:[0.7630]
# Epoch:[425/2000],data_loss:[0.7630]
# Epoch:[426/2000],data_loss:[0.7629]
# Epoch:[427/2000],data_loss:[0.7628]
# Epoch:[428/2000],data_loss:[0.7627]
# Epoch:[429/2000],data_loss:[0.7627]
# Epoch:[430/2000],data_loss:[0.7626]
# Epoch:[431/2000],data_loss:[0.7625]
# Epoch:[432/2000],data_loss:[0.7625]
# Epoch:[433/2000],data_loss:[0.7624]
# Epoch:[434/2000],data_loss:[0.7623]
# Epoch:[435/2000],data_loss:[0.7622]
# Epoch:[436/2000],data_loss:[0.7622]
# Epoch:[437/2000],data_loss:[0.7621]
# Epoch:[438/2000],data_loss:[0.7620]
# Epoch:[439/2000],data_loss:[0.7620]
# Epoch:[440/2000],data_loss:[0.7619]
# Epoch:[441/2000],data_loss:[0.7618]
# Epoch:[442/2000],data_loss:[0.7617]
# Epoch:[443/2000],data_loss:[0.7617]
# Epoch:[444/2000],data_loss:[0.7616]
# Epoch:[445/2000],data_loss:[0.7615]
# Epoch:[446/2000],data_loss:[0.7615]
# Epoch:[447/2000],data_loss:[0.7614]
# Epoch:[448/2000],data_loss:[0.7613]
# Epoch:[449/2000],data_loss:[0.7613]
# Epoch:[450/2000],data_loss:[0.7612]
# Epoch:[451/2000],data_loss:[0.7611]
# Epoch:[452/2000],data_loss:[0.7611]
# Epoch:[453/2000],data_loss:[0.7610]
# Epoch:[454/2000],data_loss:[0.7609]
# Epoch:[455/2000],data_loss:[0.7609]
# Epoch:[456/2000],data_loss:[0.7608]
# Epoch:[457/2000],data_loss:[0.7607]
# Epoch:[458/2000],data_loss:[0.7607]
# Epoch:[459/2000],data_loss:[0.7606]
# Epoch:[460/2000],data_loss:[0.7605]
# Epoch:[461/2000],data_loss:[0.7605]
# Epoch:[462/2000],data_loss:[0.7604]
# Epoch:[463/2000],data_loss:[0.7603]
# Epoch:[464/2000],data_loss:[0.7603]
# Epoch:[465/2000],data_loss:[0.7602]
# Epoch:[466/2000],data_loss:[0.7601]
# Epoch:[467/2000],data_loss:[0.7601]
# Epoch:[468/2000],data_loss:[0.7600]
# Epoch:[469/2000],data_loss:[0.7600]
# Epoch:[470/2000],data_loss:[0.7599]
# Epoch:[471/2000],data_loss:[0.7598]
# Epoch:[472/2000],data_loss:[0.7598]
# Epoch:[473/2000],data_loss:[0.7597]
# Epoch:[474/2000],data_loss:[0.7596]
# Epoch:[475/2000],data_loss:[0.7596]
# Epoch:[476/2000],data_loss:[0.7595]
# Epoch:[477/2000],data_loss:[0.7595]
# Epoch:[478/2000],data_loss:[0.7594]
# Epoch:[479/2000],data_loss:[0.7593]
# Epoch:[480/2000],data_loss:[0.7593]
# Epoch:[481/2000],data_loss:[0.7592]
# Epoch:[482/2000],data_loss:[0.7591]
# Epoch:[483/2000],data_loss:[0.7591]
# Epoch:[484/2000],data_loss:[0.7590]
# Epoch:[485/2000],data_loss:[0.7590]
# Epoch:[486/2000],data_loss:[0.7589]
# Epoch:[487/2000],data_loss:[0.7589]
# Epoch:[488/2000],data_loss:[0.7588]
# Epoch:[489/2000],data_loss:[0.7587]
# Epoch:[490/2000],data_loss:[0.7587]
# Epoch:[491/2000],data_loss:[0.7586]
# Epoch:[492/2000],data_loss:[0.7586]
# Epoch:[493/2000],data_loss:[0.7585]
# Epoch:[494/2000],data_loss:[0.7584]
# Epoch:[495/2000],data_loss:[0.7584]
# Epoch:[496/2000],data_loss:[0.7583]
# Epoch:[497/2000],data_loss:[0.7583]
# Epoch:[498/2000],data_loss:[0.7582]
# Epoch:[499/2000],data_loss:[0.7582]
# Epoch:[500/2000],data_loss:[0.7581]
# Epoch:[501/2000],data_loss:[0.7580]
# Epoch:[502/2000],data_loss:[0.7580]
# Epoch:[503/2000],data_loss:[0.7579]
# Epoch:[504/2000],data_loss:[0.7579]
# Epoch:[505/2000],data_loss:[0.7578]
# Epoch:[506/2000],data_loss:[0.7578]
# Epoch:[507/2000],data_loss:[0.7577]
# Epoch:[508/2000],data_loss:[0.7577]
# Epoch:[509/2000],data_loss:[0.7576]
# Epoch:[510/2000],data_loss:[0.7576]
# Epoch:[511/2000],data_loss:[0.7575]
# Epoch:[512/2000],data_loss:[0.7574]
# Epoch:[513/2000],data_loss:[0.7574]
# Epoch:[514/2000],data_loss:[0.7573]
# Epoch:[515/2000],data_loss:[0.7573]
# Epoch:[516/2000],data_loss:[0.7572]
# Epoch:[517/2000],data_loss:[0.7572]
# Epoch:[518/2000],data_loss:[0.7571]
# Epoch:[519/2000],data_loss:[0.7571]
# Epoch:[520/2000],data_loss:[0.7570]
# Epoch:[521/2000],data_loss:[0.7570]
# Epoch:[522/2000],data_loss:[0.7569]
# Epoch:[523/2000],data_loss:[0.7569]
# Epoch:[524/2000],data_loss:[0.7568]
# Epoch:[525/2000],data_loss:[0.7568]
# Epoch:[526/2000],data_loss:[0.7567]
# Epoch:[527/2000],data_loss:[0.7567]
# Epoch:[528/2000],data_loss:[0.7566]
# Epoch:[529/2000],data_loss:[0.7566]
# Epoch:[530/2000],data_loss:[0.7565]
# Epoch:[531/2000],data_loss:[0.7565]
# Epoch:[532/2000],data_loss:[0.7564]
# Epoch:[533/2000],data_loss:[0.7564]
# Epoch:[534/2000],data_loss:[0.7563]
# Epoch:[535/2000],data_loss:[0.7563]
# Epoch:[536/2000],data_loss:[0.7562]
# Epoch:[537/2000],data_loss:[0.7562]
# Epoch:[538/2000],data_loss:[0.7561]
# Epoch:[539/2000],data_loss:[0.7561]
# Epoch:[540/2000],data_loss:[0.7560]
# Epoch:[541/2000],data_loss:[0.7560]
# Epoch:[542/2000],data_loss:[0.7559]
# Epoch:[543/2000],data_loss:[0.7559]
# Epoch:[544/2000],data_loss:[0.7558]
# Epoch:[545/2000],data_loss:[0.7558]
# Epoch:[546/2000],data_loss:[0.7557]
# Epoch:[547/2000],data_loss:[0.7557]
# Epoch:[548/2000],data_loss:[0.7556]
# Epoch:[549/2000],data_loss:[0.7556]
# Epoch:[550/2000],data_loss:[0.7556]
# Epoch:[551/2000],data_loss:[0.7555]
# Epoch:[552/2000],data_loss:[0.7555]
# Epoch:[553/2000],data_loss:[0.7554]
# Epoch:[554/2000],data_loss:[0.7554]
# Epoch:[555/2000],data_loss:[0.7553]
# Epoch:[556/2000],data_loss:[0.7553]
# Epoch:[557/2000],data_loss:[0.7552]
# Epoch:[558/2000],data_loss:[0.7552]
# Epoch:[559/2000],data_loss:[0.7551]
# Epoch:[560/2000],data_loss:[0.7551]
# Epoch:[561/2000],data_loss:[0.7551]
# Epoch:[562/2000],data_loss:[0.7550]
# Epoch:[563/2000],data_loss:[0.7550]
# Epoch:[564/2000],data_loss:[0.7549]
# Epoch:[565/2000],data_loss:[0.7549]
# Epoch:[566/2000],data_loss:[0.7548]
# Epoch:[567/2000],data_loss:[0.7548]
# Epoch:[568/2000],data_loss:[0.7548]
# Epoch:[569/2000],data_loss:[0.7547]
# Epoch:[570/2000],data_loss:[0.7547]
# Epoch:[571/2000],data_loss:[0.7546]
# Epoch:[572/2000],data_loss:[0.7546]
# Epoch:[573/2000],data_loss:[0.7545]
# Epoch:[574/2000],data_loss:[0.7545]
# Epoch:[575/2000],data_loss:[0.7545]
# Epoch:[576/2000],data_loss:[0.7544]
# Epoch:[577/2000],data_loss:[0.7544]
# Epoch:[578/2000],data_loss:[0.7543]
# Epoch:[579/2000],data_loss:[0.7543]
# Epoch:[580/2000],data_loss:[0.7542]
# Epoch:[581/2000],data_loss:[0.7542]
# Epoch:[582/2000],data_loss:[0.7542]
# Epoch:[583/2000],data_loss:[0.7541]
# Epoch:[584/2000],data_loss:[0.7541]
# Epoch:[585/2000],data_loss:[0.7540]
# Epoch:[586/2000],data_loss:[0.7540]
# Epoch:[587/2000],data_loss:[0.7540]
# Epoch:[588/2000],data_loss:[0.7539]
# Epoch:[589/2000],data_loss:[0.7539]
# Epoch:[590/2000],data_loss:[0.7538]
# Epoch:[591/2000],data_loss:[0.7538]
# Epoch:[592/2000],data_loss:[0.7538]
# Epoch:[593/2000],data_loss:[0.7537]
# Epoch:[594/2000],data_loss:[0.7537]
# Epoch:[595/2000],data_loss:[0.7536]
# Epoch:[596/2000],data_loss:[0.7536]
# Epoch:[597/2000],data_loss:[0.7536]
# Epoch:[598/2000],data_loss:[0.7535]
# Epoch:[599/2000],data_loss:[0.7535]
# Epoch:[600/2000],data_loss:[0.7535]
# Epoch:[601/2000],data_loss:[0.7534]
# Epoch:[602/2000],data_loss:[0.7534]
# Epoch:[603/2000],data_loss:[0.7533]
# Epoch:[604/2000],data_loss:[0.7533]
# Epoch:[605/2000],data_loss:[0.7533]
# Epoch:[606/2000],data_loss:[0.7532]
# Epoch:[607/2000],data_loss:[0.7532]
# Epoch:[608/2000],data_loss:[0.7532]
# Epoch:[609/2000],data_loss:[0.7531]
# Epoch:[610/2000],data_loss:[0.7531]
# Epoch:[611/2000],data_loss:[0.7530]
# Epoch:[612/2000],data_loss:[0.7530]
# Epoch:[613/2000],data_loss:[0.7530]
# Epoch:[614/2000],data_loss:[0.7529]
# Epoch:[615/2000],data_loss:[0.7529]
# Epoch:[616/2000],data_loss:[0.7529]
# Epoch:[617/2000],data_loss:[0.7528]
# Epoch:[618/2000],data_loss:[0.7528]
# Epoch:[619/2000],data_loss:[0.7528]
# Epoch:[620/2000],data_loss:[0.7527]
# Epoch:[621/2000],data_loss:[0.7527]
# Epoch:[622/2000],data_loss:[0.7527]
# Epoch:[623/2000],data_loss:[0.7526]
# Epoch:[624/2000],data_loss:[0.7526]
# Epoch:[625/2000],data_loss:[0.7526]
# Epoch:[626/2000],data_loss:[0.7525]
# Epoch:[627/2000],data_loss:[0.7525]
# Epoch:[628/2000],data_loss:[0.7525]
# Epoch:[629/2000],data_loss:[0.7524]
# Epoch:[630/2000],data_loss:[0.7524]
# Epoch:[631/2000],data_loss:[0.7524]
# Epoch:[632/2000],data_loss:[0.7523]
# Epoch:[633/2000],data_loss:[0.7523]
# Epoch:[634/2000],data_loss:[0.7523]
# Epoch:[635/2000],data_loss:[0.7522]
# Epoch:[636/2000],data_loss:[0.7522]
# Epoch:[637/2000],data_loss:[0.7522]
# Epoch:[638/2000],data_loss:[0.7521]
# Epoch:[639/2000],data_loss:[0.7521]
# Epoch:[640/2000],data_loss:[0.7521]
# Epoch:[641/2000],data_loss:[0.7520]
# Epoch:[642/2000],data_loss:[0.7520]
# Epoch:[643/2000],data_loss:[0.7520]
# Epoch:[644/2000],data_loss:[0.7519]
# Epoch:[645/2000],data_loss:[0.7519]
# Epoch:[646/2000],data_loss:[0.7519]
# Epoch:[647/2000],data_loss:[0.7518]
# Epoch:[648/2000],data_loss:[0.7518]
# Epoch:[649/2000],data_loss:[0.7518]
# Epoch:[650/2000],data_loss:[0.7517]
# Epoch:[651/2000],data_loss:[0.7517]
# Epoch:[652/2000],data_loss:[0.7517]
# Epoch:[653/2000],data_loss:[0.7516]
# Epoch:[654/2000],data_loss:[0.7516]
# Epoch:[655/2000],data_loss:[0.7516]
# Epoch:[656/2000],data_loss:[0.7516]
# Epoch:[657/2000],data_loss:[0.7515]
# Epoch:[658/2000],data_loss:[0.7515]
# Epoch:[659/2000],data_loss:[0.7515]
# Epoch:[660/2000],data_loss:[0.7514]
# Epoch:[661/2000],data_loss:[0.7514]
# Epoch:[662/2000],data_loss:[0.7514]
# Epoch:[663/2000],data_loss:[0.7513]
# Epoch:[664/2000],data_loss:[0.7513]
# Epoch:[665/2000],data_loss:[0.7513]
# Epoch:[666/2000],data_loss:[0.7513]
# Epoch:[667/2000],data_loss:[0.7512]
# Epoch:[668/2000],data_loss:[0.7512]
# Epoch:[669/2000],data_loss:[0.7512]
# Epoch:[670/2000],data_loss:[0.7511]
# Epoch:[671/2000],data_loss:[0.7511]
# Epoch:[672/2000],data_loss:[0.7511]
# Epoch:[673/2000],data_loss:[0.7511]
# Epoch:[674/2000],data_loss:[0.7510]
# Epoch:[675/2000],data_loss:[0.7510]
# Epoch:[676/2000],data_loss:[0.7510]
# Epoch:[677/2000],data_loss:[0.7509]
# Epoch:[678/2000],data_loss:[0.7509]
# Epoch:[679/2000],data_loss:[0.7509]
# Epoch:[680/2000],data_loss:[0.7509]
# Epoch:[681/2000],data_loss:[0.7508]
# Epoch:[682/2000],data_loss:[0.7508]
# Epoch:[683/2000],data_loss:[0.7508]
# Epoch:[684/2000],data_loss:[0.7508]
# Epoch:[685/2000],data_loss:[0.7507]
# Epoch:[686/2000],data_loss:[0.7507]
# Epoch:[687/2000],data_loss:[0.7507]
# Epoch:[688/2000],data_loss:[0.7506]
# Epoch:[689/2000],data_loss:[0.7506]
# Epoch:[690/2000],data_loss:[0.7506]
# Epoch:[691/2000],data_loss:[0.7506]
# Epoch:[692/2000],data_loss:[0.7505]
# Epoch:[693/2000],data_loss:[0.7505]
# Epoch:[694/2000],data_loss:[0.7505]
# Epoch:[695/2000],data_loss:[0.7505]
# Epoch:[696/2000],data_loss:[0.7504]
# Epoch:[697/2000],data_loss:[0.7504]
# Epoch:[698/2000],data_loss:[0.7504]
# Epoch:[699/2000],data_loss:[0.7504]
# Epoch:[700/2000],data_loss:[0.7503]
# Epoch:[701/2000],data_loss:[0.7503]
# Epoch:[702/2000],data_loss:[0.7503]
# Epoch:[703/2000],data_loss:[0.7503]
# Epoch:[704/2000],data_loss:[0.7502]
# Epoch:[705/2000],data_loss:[0.7502]
# Epoch:[706/2000],data_loss:[0.7502]
# Epoch:[707/2000],data_loss:[0.7502]
# Epoch:[708/2000],data_loss:[0.7501]
# Epoch:[709/2000],data_loss:[0.7501]
# Epoch:[710/2000],data_loss:[0.7501]
# Epoch:[711/2000],data_loss:[0.7501]
# Epoch:[712/2000],data_loss:[0.7500]
# Epoch:[713/2000],data_loss:[0.7500]
# Epoch:[714/2000],data_loss:[0.7500]
# Epoch:[715/2000],data_loss:[0.7500]
# Epoch:[716/2000],data_loss:[0.7499]
# Epoch:[717/2000],data_loss:[0.7499]
# Epoch:[718/2000],data_loss:[0.7499]
# Epoch:[719/2000],data_loss:[0.7499]
# Epoch:[720/2000],data_loss:[0.7499]
# Epoch:[721/2000],data_loss:[0.7498]
# Epoch:[722/2000],data_loss:[0.7498]
# Epoch:[723/2000],data_loss:[0.7498]
# Epoch:[724/2000],data_loss:[0.7498]
# Epoch:[725/2000],data_loss:[0.7497]
# Epoch:[726/2000],data_loss:[0.7497]
# Epoch:[727/2000],data_loss:[0.7497]
# Epoch:[728/2000],data_loss:[0.7497]
# Epoch:[729/2000],data_loss:[0.7496]
# Epoch:[730/2000],data_loss:[0.7496]
# Epoch:[731/2000],data_loss:[0.7496]
# Epoch:[732/2000],data_loss:[0.7496]
# Epoch:[733/2000],data_loss:[0.7496]
# Epoch:[734/2000],data_loss:[0.7495]
# Epoch:[735/2000],data_loss:[0.7495]
# Epoch:[736/2000],data_loss:[0.7495]
# Epoch:[737/2000],data_loss:[0.7495]
# Epoch:[738/2000],data_loss:[0.7494]
# Epoch:[739/2000],data_loss:[0.7494]
# Epoch:[740/2000],data_loss:[0.7494]
# Epoch:[741/2000],data_loss:[0.7494]
# Epoch:[742/2000],data_loss:[0.7494]
# Epoch:[743/2000],data_loss:[0.7493]
# Epoch:[744/2000],data_loss:[0.7493]
# Epoch:[745/2000],data_loss:[0.7493]
# Epoch:[746/2000],data_loss:[0.7493]
# Epoch:[747/2000],data_loss:[0.7493]
# Epoch:[748/2000],data_loss:[0.7492]
# Epoch:[749/2000],data_loss:[0.7492]
# Epoch:[750/2000],data_loss:[0.7492]
# Epoch:[751/2000],data_loss:[0.7492]
# Epoch:[752/2000],data_loss:[0.7492]
# Epoch:[753/2000],data_loss:[0.7491]
# Epoch:[754/2000],data_loss:[0.7491]
# Epoch:[755/2000],data_loss:[0.7491]
# Epoch:[756/2000],data_loss:[0.7491]
# Epoch:[757/2000],data_loss:[0.7491]
# Epoch:[758/2000],data_loss:[0.7490]
# Epoch:[759/2000],data_loss:[0.7490]
# Epoch:[760/2000],data_loss:[0.7490]
# Epoch:[761/2000],data_loss:[0.7490]
# Epoch:[762/2000],data_loss:[0.7490]
# Epoch:[763/2000],data_loss:[0.7489]
# Epoch:[764/2000],data_loss:[0.7489]
# Epoch:[765/2000],data_loss:[0.7489]
# Epoch:[766/2000],data_loss:[0.7489]
# Epoch:[767/2000],data_loss:[0.7489]
# Epoch:[768/2000],data_loss:[0.7488]
# Epoch:[769/2000],data_loss:[0.7488]
# Epoch:[770/2000],data_loss:[0.7488]
# Epoch:[771/2000],data_loss:[0.7488]
# Epoch:[772/2000],data_loss:[0.7488]
# Epoch:[773/2000],data_loss:[0.7487]
# Epoch:[774/2000],data_loss:[0.7487]
# Epoch:[775/2000],data_loss:[0.7487]
# Epoch:[776/2000],data_loss:[0.7487]
# Epoch:[777/2000],data_loss:[0.7487]
# Epoch:[778/2000],data_loss:[0.7487]
# Epoch:[779/2000],data_loss:[0.7486]
# Epoch:[780/2000],data_loss:[0.7486]
# Epoch:[781/2000],data_loss:[0.7486]
# Epoch:[782/2000],data_loss:[0.7486]
# Epoch:[783/2000],data_loss:[0.7486]
# Epoch:[784/2000],data_loss:[0.7485]
# Epoch:[785/2000],data_loss:[0.7485]
# Epoch:[786/2000],data_loss:[0.7485]
# Epoch:[787/2000],data_loss:[0.7485]
# Epoch:[788/2000],data_loss:[0.7485]
# Epoch:[789/2000],data_loss:[0.7485]
# Epoch:[790/2000],data_loss:[0.7484]
# Epoch:[791/2000],data_loss:[0.7484]
# Epoch:[792/2000],data_loss:[0.7484]
# Epoch:[793/2000],data_loss:[0.7484]
# Epoch:[794/2000],data_loss:[0.7484]
# Epoch:[795/2000],data_loss:[0.7484]
# Epoch:[796/2000],data_loss:[0.7483]
# Epoch:[797/2000],data_loss:[0.7483]
# Epoch:[798/2000],data_loss:[0.7483]
# Epoch:[799/2000],data_loss:[0.7483]
# Epoch:[800/2000],data_loss:[0.7483]
# Epoch:[801/2000],data_loss:[0.7483]
# Epoch:[802/2000],data_loss:[0.7482]
# Epoch:[803/2000],data_loss:[0.7482]
# Epoch:[804/2000],data_loss:[0.7482]
# Epoch:[805/2000],data_loss:[0.7482]
# Epoch:[806/2000],data_loss:[0.7482]
# Epoch:[807/2000],data_loss:[0.7482]
# Epoch:[808/2000],data_loss:[0.7481]
# Epoch:[809/2000],data_loss:[0.7481]
# Epoch:[810/2000],data_loss:[0.7481]
# Epoch:[811/2000],data_loss:[0.7481]
# Epoch:[812/2000],data_loss:[0.7481]
# Epoch:[813/2000],data_loss:[0.7481]
# Epoch:[814/2000],data_loss:[0.7480]
# Epoch:[815/2000],data_loss:[0.7480]
# Epoch:[816/2000],data_loss:[0.7480]
# Epoch:[817/2000],data_loss:[0.7480]
# Epoch:[818/2000],data_loss:[0.7480]
# Epoch:[819/2000],data_loss:[0.7480]
# Epoch:[820/2000],data_loss:[0.7480]
# Epoch:[821/2000],data_loss:[0.7479]
# Epoch:[822/2000],data_loss:[0.7479]
# Epoch:[823/2000],data_loss:[0.7479]
# Epoch:[824/2000],data_loss:[0.7479]
# Epoch:[825/2000],data_loss:[0.7479]
# Epoch:[826/2000],data_loss:[0.7479]
# Epoch:[827/2000],data_loss:[0.7478]
# Epoch:[828/2000],data_loss:[0.7478]
# Epoch:[829/2000],data_loss:[0.7478]
# Epoch:[830/2000],data_loss:[0.7478]
# Epoch:[831/2000],data_loss:[0.7478]
# Epoch:[832/2000],data_loss:[0.7478]
# Epoch:[833/2000],data_loss:[0.7478]
# Epoch:[834/2000],data_loss:[0.7477]
# Epoch:[835/2000],data_loss:[0.7477]
# Epoch:[836/2000],data_loss:[0.7477]
# Epoch:[837/2000],data_loss:[0.7477]
# Epoch:[838/2000],data_loss:[0.7477]
# Epoch:[839/2000],data_loss:[0.7477]
# Epoch:[840/2000],data_loss:[0.7477]
# Epoch:[841/2000],data_loss:[0.7476]
# Epoch:[842/2000],data_loss:[0.7476]
# Epoch:[843/2000],data_loss:[0.7476]
# Epoch:[844/2000],data_loss:[0.7476]
# Epoch:[845/2000],data_loss:[0.7476]
# Epoch:[846/2000],data_loss:[0.7476]
# Epoch:[847/2000],data_loss:[0.7476]
# Epoch:[848/2000],data_loss:[0.7476]
# Epoch:[849/2000],data_loss:[0.7475]
# Epoch:[850/2000],data_loss:[0.7475]
# Epoch:[851/2000],data_loss:[0.7475]
# Epoch:[852/2000],data_loss:[0.7475]
# Epoch:[853/2000],data_loss:[0.7475]
# Epoch:[854/2000],data_loss:[0.7475]
# Epoch:[855/2000],data_loss:[0.7475]
# Epoch:[856/2000],data_loss:[0.7474]
# Epoch:[857/2000],data_loss:[0.7474]
# Epoch:[858/2000],data_loss:[0.7474]
# Epoch:[859/2000],data_loss:[0.7474]
# Epoch:[860/2000],data_loss:[0.7474]
# Epoch:[861/2000],data_loss:[0.7474]
# Epoch:[862/2000],data_loss:[0.7474]
# Epoch:[863/2000],data_loss:[0.7474]
# Epoch:[864/2000],data_loss:[0.7473]
# Epoch:[865/2000],data_loss:[0.7473]
# Epoch:[866/2000],data_loss:[0.7473]
# Epoch:[867/2000],data_loss:[0.7473]
# Epoch:[868/2000],data_loss:[0.7473]
# Epoch:[869/2000],data_loss:[0.7473]
# Epoch:[870/2000],data_loss:[0.7473]
# Epoch:[871/2000],data_loss:[0.7473]
# Epoch:[872/2000],data_loss:[0.7472]
# Epoch:[873/2000],data_loss:[0.7472]
# Epoch:[874/2000],data_loss:[0.7472]
# Epoch:[875/2000],data_loss:[0.7472]
# Epoch:[876/2000],data_loss:[0.7472]
# Epoch:[877/2000],data_loss:[0.7472]
# Epoch:[878/2000],data_loss:[0.7472]
# Epoch:[879/2000],data_loss:[0.7472]
# Epoch:[880/2000],data_loss:[0.7471]
# Epoch:[881/2000],data_loss:[0.7471]
# Epoch:[882/2000],data_loss:[0.7471]
# Epoch:[883/2000],data_loss:[0.7471]
# Epoch:[884/2000],data_loss:[0.7471]
# Epoch:[885/2000],data_loss:[0.7471]
# Epoch:[886/2000],data_loss:[0.7471]
# Epoch:[887/2000],data_loss:[0.7471]
# Epoch:[888/2000],data_loss:[0.7471]
# Epoch:[889/2000],data_loss:[0.7470]
# Epoch:[890/2000],data_loss:[0.7470]
# Epoch:[891/2000],data_loss:[0.7470]
# Epoch:[892/2000],data_loss:[0.7470]
# Epoch:[893/2000],data_loss:[0.7470]
# Epoch:[894/2000],data_loss:[0.7470]
# Epoch:[895/2000],data_loss:[0.7470]
# Epoch:[896/2000],data_loss:[0.7470]
# Epoch:[897/2000],data_loss:[0.7469]
# Epoch:[898/2000],data_loss:[0.7469]
# Epoch:[899/2000],data_loss:[0.7469]
# Epoch:[900/2000],data_loss:[0.7469]
# Epoch:[901/2000],data_loss:[0.7469]
# Epoch:[902/2000],data_loss:[0.7469]
# Epoch:[903/2000],data_loss:[0.7469]
# Epoch:[904/2000],data_loss:[0.7469]
# Epoch:[905/2000],data_loss:[0.7469]
# Epoch:[906/2000],data_loss:[0.7469]
# Epoch:[907/2000],data_loss:[0.7468]
# Epoch:[908/2000],data_loss:[0.7468]
# Epoch:[909/2000],data_loss:[0.7468]
# Epoch:[910/2000],data_loss:[0.7468]
# Epoch:[911/2000],data_loss:[0.7468]
# Epoch:[912/2000],data_loss:[0.7468]
# Epoch:[913/2000],data_loss:[0.7468]
# Epoch:[914/2000],data_loss:[0.7468]
# Epoch:[915/2000],data_loss:[0.7468]
# Epoch:[916/2000],data_loss:[0.7467]
# Epoch:[917/2000],data_loss:[0.7467]
# Epoch:[918/2000],data_loss:[0.7467]
# Epoch:[919/2000],data_loss:[0.7467]
# Epoch:[920/2000],data_loss:[0.7467]
# Epoch:[921/2000],data_loss:[0.7467]
# Epoch:[922/2000],data_loss:[0.7467]
# Epoch:[923/2000],data_loss:[0.7467]
# Epoch:[924/2000],data_loss:[0.7467]
# Epoch:[925/2000],data_loss:[0.7467]
# Epoch:[926/2000],data_loss:[0.7466]
# Epoch:[927/2000],data_loss:[0.7466]
# Epoch:[928/2000],data_loss:[0.7466]
# Epoch:[929/2000],data_loss:[0.7466]
# Epoch:[930/2000],data_loss:[0.7466]
# Epoch:[931/2000],data_loss:[0.7466]
# Epoch:[932/2000],data_loss:[0.7466]
# Epoch:[933/2000],data_loss:[0.7466]
# Epoch:[934/2000],data_loss:[0.7466]
# Epoch:[935/2000],data_loss:[0.7466]
# Epoch:[936/2000],data_loss:[0.7466]
# Epoch:[937/2000],data_loss:[0.7465]
# Epoch:[938/2000],data_loss:[0.7465]
# Epoch:[939/2000],data_loss:[0.7465]
# Epoch:[940/2000],data_loss:[0.7465]
# Epoch:[941/2000],data_loss:[0.7465]
# Epoch:[942/2000],data_loss:[0.7465]
# Epoch:[943/2000],data_loss:[0.7465]
# Epoch:[944/2000],data_loss:[0.7465]
# Epoch:[945/2000],data_loss:[0.7465]
# Epoch:[946/2000],data_loss:[0.7465]
# Epoch:[947/2000],data_loss:[0.7465]
# Epoch:[948/2000],data_loss:[0.7464]
# Epoch:[949/2000],data_loss:[0.7464]
# Epoch:[950/2000],data_loss:[0.7464]
# Epoch:[951/2000],data_loss:[0.7464]
# Epoch:[952/2000],data_loss:[0.7464]
# Epoch:[953/2000],data_loss:[0.7464]
# Epoch:[954/2000],data_loss:[0.7464]
# Epoch:[955/2000],data_loss:[0.7464]
# Epoch:[956/2000],data_loss:[0.7464]
# Epoch:[957/2000],data_loss:[0.7464]
# Epoch:[958/2000],data_loss:[0.7464]
# Epoch:[959/2000],data_loss:[0.7463]
# Epoch:[960/2000],data_loss:[0.7463]
# Epoch:[961/2000],data_loss:[0.7463]
# Epoch:[962/2000],data_loss:[0.7463]
# Epoch:[963/2000],data_loss:[0.7463]
# Epoch:[964/2000],data_loss:[0.7463]
# Epoch:[965/2000],data_loss:[0.7463]
# Epoch:[966/2000],data_loss:[0.7463]
# Epoch:[967/2000],data_loss:[0.7463]
# Epoch:[968/2000],data_loss:[0.7463]
# Epoch:[969/2000],data_loss:[0.7463]
# Epoch:[970/2000],data_loss:[0.7463]
# Epoch:[971/2000],data_loss:[0.7462]
# Epoch:[972/2000],data_loss:[0.7462]
# Epoch:[973/2000],data_loss:[0.7462]
# Epoch:[974/2000],data_loss:[0.7462]
# Epoch:[975/2000],data_loss:[0.7462]
# Epoch:[976/2000],data_loss:[0.7462]
# Epoch:[977/2000],data_loss:[0.7462]
# Epoch:[978/2000],data_loss:[0.7462]
# Epoch:[979/2000],data_loss:[0.7462]
# Epoch:[980/2000],data_loss:[0.7462]
# Epoch:[981/2000],data_loss:[0.7462]
# Epoch:[982/2000],data_loss:[0.7462]
# Epoch:[983/2000],data_loss:[0.7462]
# Epoch:[984/2000],data_loss:[0.7461]
# Epoch:[985/2000],data_loss:[0.7461]
# Epoch:[986/2000],data_loss:[0.7461]
# Epoch:[987/2000],data_loss:[0.7461]
# Epoch:[988/2000],data_loss:[0.7461]
# Epoch:[989/2000],data_loss:[0.7461]
# Epoch:[990/2000],data_loss:[0.7461]
# Epoch:[991/2000],data_loss:[0.7461]
# Epoch:[992/2000],data_loss:[0.7461]
# Epoch:[993/2000],data_loss:[0.7461]
# Epoch:[994/2000],data_loss:[0.7461]
# Epoch:[995/2000],data_loss:[0.7461]
# Epoch:[996/2000],data_loss:[0.7461]
# Epoch:[997/2000],data_loss:[0.7460]
# Epoch:[998/2000],data_loss:[0.7460]
# Epoch:[999/2000],data_loss:[0.7460]
# Epoch:[1000/2000],data_loss:[0.7460]
# Epoch:[1001/2000],data_loss:[0.7460]
# Epoch:[1002/2000],data_loss:[0.7460]
# Epoch:[1003/2000],data_loss:[0.7460]
# Epoch:[1004/2000],data_loss:[0.7460]
# Epoch:[1005/2000],data_loss:[0.7460]
# Epoch:[1006/2000],data_loss:[0.7460]
# Epoch:[1007/2000],data_loss:[0.7460]
# Epoch:[1008/2000],data_loss:[0.7460]
# Epoch:[1009/2000],data_loss:[0.7460]
# Epoch:[1010/2000],data_loss:[0.7460]
# Epoch:[1011/2000],data_loss:[0.7459]
# Epoch:[1012/2000],data_loss:[0.7459]
# Epoch:[1013/2000],data_loss:[0.7459]
# Epoch:[1014/2000],data_loss:[0.7459]
# Epoch:[1015/2000],data_loss:[0.7459]
# Epoch:[1016/2000],data_loss:[0.7459]
# Epoch:[1017/2000],data_loss:[0.7459]
# Epoch:[1018/2000],data_loss:[0.7459]
# Epoch:[1019/2000],data_loss:[0.7459]
# Epoch:[1020/2000],data_loss:[0.7459]
# Epoch:[1021/2000],data_loss:[0.7459]
# Epoch:[1022/2000],data_loss:[0.7459]
# Epoch:[1023/2000],data_loss:[0.7459]
# Epoch:[1024/2000],data_loss:[0.7459]
# Epoch:[1025/2000],data_loss:[0.7459]
# Epoch:[1026/2000],data_loss:[0.7458]
# Epoch:[1027/2000],data_loss:[0.7458]
# Epoch:[1028/2000],data_loss:[0.7458]
# Epoch:[1029/2000],data_loss:[0.7458]
# Epoch:[1030/2000],data_loss:[0.7458]
# Epoch:[1031/2000],data_loss:[0.7458]
# Epoch:[1032/2000],data_loss:[0.7458]
# Epoch:[1033/2000],data_loss:[0.7458]
# Epoch:[1034/2000],data_loss:[0.7458]
# Epoch:[1035/2000],data_loss:[0.7458]
# Epoch:[1036/2000],data_loss:[0.7458]
# Epoch:[1037/2000],data_loss:[0.7458]
# Epoch:[1038/2000],data_loss:[0.7458]
# Epoch:[1039/2000],data_loss:[0.7458]
# Epoch:[1040/2000],data_loss:[0.7458]
# Epoch:[1041/2000],data_loss:[0.7458]
# Epoch:[1042/2000],data_loss:[0.7457]
# Epoch:[1043/2000],data_loss:[0.7457]
# Epoch:[1044/2000],data_loss:[0.7457]
# Epoch:[1045/2000],data_loss:[0.7457]
# Epoch:[1046/2000],data_loss:[0.7457]
# Epoch:[1047/2000],data_loss:[0.7457]
# Epoch:[1048/2000],data_loss:[0.7457]
# Epoch:[1049/2000],data_loss:[0.7457]
# Epoch:[1050/2000],data_loss:[0.7457]
# Epoch:[1051/2000],data_loss:[0.7457]
# Epoch:[1052/2000],data_loss:[0.7457]
# Epoch:[1053/2000],data_loss:[0.7457]
# Epoch:[1054/2000],data_loss:[0.7457]
# Epoch:[1055/2000],data_loss:[0.7457]
# Epoch:[1056/2000],data_loss:[0.7457]
# Epoch:[1057/2000],data_loss:[0.7457]
# Epoch:[1058/2000],data_loss:[0.7457]
# Epoch:[1059/2000],data_loss:[0.7456]
# Epoch:[1060/2000],data_loss:[0.7456]
# Epoch:[1061/2000],data_loss:[0.7456]
# Epoch:[1062/2000],data_loss:[0.7456]
# Epoch:[1063/2000],data_loss:[0.7456]
# Epoch:[1064/2000],data_loss:[0.7456]
# Epoch:[1065/2000],data_loss:[0.7456]
# Epoch:[1066/2000],data_loss:[0.7456]
# Epoch:[1067/2000],data_loss:[0.7456]
# Epoch:[1068/2000],data_loss:[0.7456]
# Epoch:[1069/2000],data_loss:[0.7456]
# Epoch:[1070/2000],data_loss:[0.7456]
# Epoch:[1071/2000],data_loss:[0.7456]
# Epoch:[1072/2000],data_loss:[0.7456]
# Epoch:[1073/2000],data_loss:[0.7456]
# Epoch:[1074/2000],data_loss:[0.7456]
# Epoch:[1075/2000],data_loss:[0.7456]
# Epoch:[1076/2000],data_loss:[0.7456]
# Epoch:[1077/2000],data_loss:[0.7455]
# Epoch:[1078/2000],data_loss:[0.7455]
# Epoch:[1079/2000],data_loss:[0.7455]
# Epoch:[1080/2000],data_loss:[0.7455]
# Epoch:[1081/2000],data_loss:[0.7455]
# Epoch:[1082/2000],data_loss:[0.7455]
# Epoch:[1083/2000],data_loss:[0.7455]
# Epoch:[1084/2000],data_loss:[0.7455]
# Epoch:[1085/2000],data_loss:[0.7455]
# Epoch:[1086/2000],data_loss:[0.7455]
# Epoch:[1087/2000],data_loss:[0.7455]
# Epoch:[1088/2000],data_loss:[0.7455]
# Epoch:[1089/2000],data_loss:[0.7455]
# Epoch:[1090/2000],data_loss:[0.7455]
# Epoch:[1091/2000],data_loss:[0.7455]
# Epoch:[1092/2000],data_loss:[0.7455]
# Epoch:[1093/2000],data_loss:[0.7455]
# Epoch:[1094/2000],data_loss:[0.7455]
# Epoch:[1095/2000],data_loss:[0.7455]
# Epoch:[1096/2000],data_loss:[0.7455]
# Epoch:[1097/2000],data_loss:[0.7454]
# Epoch:[1098/2000],data_loss:[0.7454]
# Epoch:[1099/2000],data_loss:[0.7454]
# Epoch:[1100/2000],data_loss:[0.7454]
# Epoch:[1101/2000],data_loss:[0.7454]
# Epoch:[1102/2000],data_loss:[0.7454]
# Epoch:[1103/2000],data_loss:[0.7454]
# Epoch:[1104/2000],data_loss:[0.7454]
# Epoch:[1105/2000],data_loss:[0.7454]
# Epoch:[1106/2000],data_loss:[0.7454]
# Epoch:[1107/2000],data_loss:[0.7454]
# Epoch:[1108/2000],data_loss:[0.7454]
# Epoch:[1109/2000],data_loss:[0.7454]
# Epoch:[1110/2000],data_loss:[0.7454]
# Epoch:[1111/2000],data_loss:[0.7454]
# Epoch:[1112/2000],data_loss:[0.7454]
# Epoch:[1113/2000],data_loss:[0.7454]
# Epoch:[1114/2000],data_loss:[0.7454]
# Epoch:[1115/2000],data_loss:[0.7454]
# Epoch:[1116/2000],data_loss:[0.7454]
# Epoch:[1117/2000],data_loss:[0.7454]
# Epoch:[1118/2000],data_loss:[0.7454]
# Epoch:[1119/2000],data_loss:[0.7453]
# Epoch:[1120/2000],data_loss:[0.7453]
# Epoch:[1121/2000],data_loss:[0.7453]
# Epoch:[1122/2000],data_loss:[0.7453]
# Epoch:[1123/2000],data_loss:[0.7453]
# Epoch:[1124/2000],data_loss:[0.7453]
# Epoch:[1125/2000],data_loss:[0.7453]
# Epoch:[1126/2000],data_loss:[0.7453]
# Epoch:[1127/2000],data_loss:[0.7453]
# Epoch:[1128/2000],data_loss:[0.7453]
# Epoch:[1129/2000],data_loss:[0.7453]
# Epoch:[1130/2000],data_loss:[0.7453]
# Epoch:[1131/2000],data_loss:[0.7453]
# Epoch:[1132/2000],data_loss:[0.7453]
# Epoch:[1133/2000],data_loss:[0.7453]
# Epoch:[1134/2000],data_loss:[0.7453]
# Epoch:[1135/2000],data_loss:[0.7453]
# Epoch:[1136/2000],data_loss:[0.7453]
# Epoch:[1137/2000],data_loss:[0.7453]
# Epoch:[1138/2000],data_loss:[0.7453]
# Epoch:[1139/2000],data_loss:[0.7453]
# Epoch:[1140/2000],data_loss:[0.7453]
# Epoch:[1141/2000],data_loss:[0.7453]
# Epoch:[1142/2000],data_loss:[0.7452]
# Epoch:[1143/2000],data_loss:[0.7452]
# Epoch:[1144/2000],data_loss:[0.7452]
# Epoch:[1145/2000],data_loss:[0.7452]
# Epoch:[1146/2000],data_loss:[0.7452]
# Epoch:[1147/2000],data_loss:[0.7452]
# Epoch:[1148/2000],data_loss:[0.7452]
# Epoch:[1149/2000],data_loss:[0.7452]
# Epoch:[1150/2000],data_loss:[0.7452]
# Epoch:[1151/2000],data_loss:[0.7452]
# Epoch:[1152/2000],data_loss:[0.7452]
# Epoch:[1153/2000],data_loss:[0.7452]
# Epoch:[1154/2000],data_loss:[0.7452]
# Epoch:[1155/2000],data_loss:[0.7452]
# Epoch:[1156/2000],data_loss:[0.7452]
# Epoch:[1157/2000],data_loss:[0.7452]
# Epoch:[1158/2000],data_loss:[0.7452]
# Epoch:[1159/2000],data_loss:[0.7452]
# Epoch:[1160/2000],data_loss:[0.7452]
# Epoch:[1161/2000],data_loss:[0.7452]
# Epoch:[1162/2000],data_loss:[0.7452]
# Epoch:[1163/2000],data_loss:[0.7452]
# Epoch:[1164/2000],data_loss:[0.7452]
# Epoch:[1165/2000],data_loss:[0.7452]
# Epoch:[1166/2000],data_loss:[0.7452]
# Epoch:[1167/2000],data_loss:[0.7451]
# Epoch:[1168/2000],data_loss:[0.7451]
# Epoch:[1169/2000],data_loss:[0.7451]
# Epoch:[1170/2000],data_loss:[0.7451]
# Epoch:[1171/2000],data_loss:[0.7451]
# Epoch:[1172/2000],data_loss:[0.7451]
# Epoch:[1173/2000],data_loss:[0.7451]
# Epoch:[1174/2000],data_loss:[0.7451]
# Epoch:[1175/2000],data_loss:[0.7451]
# Epoch:[1176/2000],data_loss:[0.7451]
# Epoch:[1177/2000],data_loss:[0.7451]
# Epoch:[1178/2000],data_loss:[0.7451]
# Epoch:[1179/2000],data_loss:[0.7451]
# Epoch:[1180/2000],data_loss:[0.7451]
# Epoch:[1181/2000],data_loss:[0.7451]
# Epoch:[1182/2000],data_loss:[0.7451]
# Epoch:[1183/2000],data_loss:[0.7451]
# Epoch:[1184/2000],data_loss:[0.7451]
# Epoch:[1185/2000],data_loss:[0.7451]
# Epoch:[1186/2000],data_loss:[0.7451]
# Epoch:[1187/2000],data_loss:[0.7451]
# Epoch:[1188/2000],data_loss:[0.7451]
# Epoch:[1189/2000],data_loss:[0.7451]
# Epoch:[1190/2000],data_loss:[0.7451]
# Epoch:[1191/2000],data_loss:[0.7451]
# Epoch:[1192/2000],data_loss:[0.7451]
# Epoch:[1193/2000],data_loss:[0.7451]
# Epoch:[1194/2000],data_loss:[0.7451]
# Epoch:[1195/2000],data_loss:[0.7451]
# Epoch:[1196/2000],data_loss:[0.7450]
# Epoch:[1197/2000],data_loss:[0.7450]
# Epoch:[1198/2000],data_loss:[0.7450]
# Epoch:[1199/2000],data_loss:[0.7450]
# Epoch:[1200/2000],data_loss:[0.7450]
# Epoch:[1201/2000],data_loss:[0.7450]
# Epoch:[1202/2000],data_loss:[0.7450]
# Epoch:[1203/2000],data_loss:[0.7450]
# Epoch:[1204/2000],data_loss:[0.7450]
# Epoch:[1205/2000],data_loss:[0.7450]
# Epoch:[1206/2000],data_loss:[0.7450]
# Epoch:[1207/2000],data_loss:[0.7450]
# Epoch:[1208/2000],data_loss:[0.7450]
# Epoch:[1209/2000],data_loss:[0.7450]
# Epoch:[1210/2000],data_loss:[0.7450]
# Epoch:[1211/2000],data_loss:[0.7450]
# Epoch:[1212/2000],data_loss:[0.7450]
# Epoch:[1213/2000],data_loss:[0.7450]
# Epoch:[1214/2000],data_loss:[0.7450]
# Epoch:[1215/2000],data_loss:[0.7450]
# Epoch:[1216/2000],data_loss:[0.7450]
# Epoch:[1217/2000],data_loss:[0.7450]
# Epoch:[1218/2000],data_loss:[0.7450]
# Epoch:[1219/2000],data_loss:[0.7450]
# Epoch:[1220/2000],data_loss:[0.7450]
# Epoch:[1221/2000],data_loss:[0.7450]
# Epoch:[1222/2000],data_loss:[0.7450]
# Epoch:[1223/2000],data_loss:[0.7450]
# Epoch:[1224/2000],data_loss:[0.7450]
# Epoch:[1225/2000],data_loss:[0.7450]
# Epoch:[1226/2000],data_loss:[0.7450]
# Epoch:[1227/2000],data_loss:[0.7449]
# Epoch:[1228/2000],data_loss:[0.7449]
# Epoch:[1229/2000],data_loss:[0.7449]
# Epoch:[1230/2000],data_loss:[0.7449]
# Epoch:[1231/2000],data_loss:[0.7449]
# Epoch:[1232/2000],data_loss:[0.7449]
# Epoch:[1233/2000],data_loss:[0.7449]
# Epoch:[1234/2000],data_loss:[0.7449]
# Epoch:[1235/2000],data_loss:[0.7449]
# Epoch:[1236/2000],data_loss:[0.7449]
# Epoch:[1237/2000],data_loss:[0.7449]
# Epoch:[1238/2000],data_loss:[0.7449]
# Epoch:[1239/2000],data_loss:[0.7449]
# Epoch:[1240/2000],data_loss:[0.7449]
# Epoch:[1241/2000],data_loss:[0.7449]
# Epoch:[1242/2000],data_loss:[0.7449]
# Epoch:[1243/2000],data_loss:[0.7449]
# Epoch:[1244/2000],data_loss:[0.7449]
# Epoch:[1245/2000],data_loss:[0.7449]
# Epoch:[1246/2000],data_loss:[0.7449]
# Epoch:[1247/2000],data_loss:[0.7449]
# Epoch:[1248/2000],data_loss:[0.7449]
# Epoch:[1249/2000],data_loss:[0.7449]
# Epoch:[1250/2000],data_loss:[0.7449]
# Epoch:[1251/2000],data_loss:[0.7449]
# Epoch:[1252/2000],data_loss:[0.7449]
# Epoch:[1253/2000],data_loss:[0.7449]
# Epoch:[1254/2000],data_loss:[0.7449]
# Epoch:[1255/2000],data_loss:[0.7449]
# Epoch:[1256/2000],data_loss:[0.7449]
# Epoch:[1257/2000],data_loss:[0.7449]
# Epoch:[1258/2000],data_loss:[0.7449]
# Epoch:[1259/2000],data_loss:[0.7449]
# Epoch:[1260/2000],data_loss:[0.7449]
# Epoch:[1261/2000],data_loss:[0.7449]
# Epoch:[1262/2000],data_loss:[0.7448]
# Epoch:[1263/2000],data_loss:[0.7448]
# Epoch:[1264/2000],data_loss:[0.7448]
# Epoch:[1265/2000],data_loss:[0.7448]
# Epoch:[1266/2000],data_loss:[0.7448]
# Epoch:[1267/2000],data_loss:[0.7448]
# Epoch:[1268/2000],data_loss:[0.7448]
# Epoch:[1269/2000],data_loss:[0.7448]
# Epoch:[1270/2000],data_loss:[0.7448]
# Epoch:[1271/2000],data_loss:[0.7448]
# Epoch:[1272/2000],data_loss:[0.7448]
# Epoch:[1273/2000],data_loss:[0.7448]
# Epoch:[1274/2000],data_loss:[0.7448]
# Epoch:[1275/2000],data_loss:[0.7448]
# Epoch:[1276/2000],data_loss:[0.7448]
# Epoch:[1277/2000],data_loss:[0.7448]
# Epoch:[1278/2000],data_loss:[0.7448]
# Epoch:[1279/2000],data_loss:[0.7448]
# Epoch:[1280/2000],data_loss:[0.7448]
# Epoch:[1281/2000],data_loss:[0.7448]
# Epoch:[1282/2000],data_loss:[0.7448]
# Epoch:[1283/2000],data_loss:[0.7448]
# Epoch:[1284/2000],data_loss:[0.7448]
# Epoch:[1285/2000],data_loss:[0.7448]
# Epoch:[1286/2000],data_loss:[0.7448]
# Epoch:[1287/2000],data_loss:[0.7448]
# Epoch:[1288/2000],data_loss:[0.7448]
# Epoch:[1289/2000],data_loss:[0.7448]
# Epoch:[1290/2000],data_loss:[0.7448]
# Epoch:[1291/2000],data_loss:[0.7448]
# Epoch:[1292/2000],data_loss:[0.7448]
# Epoch:[1293/2000],data_loss:[0.7448]
# Epoch:[1294/2000],data_loss:[0.7448]
# Epoch:[1295/2000],data_loss:[0.7448]
# Epoch:[1296/2000],data_loss:[0.7448]
# Epoch:[1297/2000],data_loss:[0.7448]
# Epoch:[1298/2000],data_loss:[0.7448]
# Epoch:[1299/2000],data_loss:[0.7448]
# Epoch:[1300/2000],data_loss:[0.7448]
# Epoch:[1301/2000],data_loss:[0.7448]
# Epoch:[1302/2000],data_loss:[0.7447]
# Epoch:[1303/2000],data_loss:[0.7447]
# Epoch:[1304/2000],data_loss:[0.7447]
# Epoch:[1305/2000],data_loss:[0.7447]
# Epoch:[1306/2000],data_loss:[0.7447]
# Epoch:[1307/2000],data_loss:[0.7447]
# Epoch:[1308/2000],data_loss:[0.7447]
# Epoch:[1309/2000],data_loss:[0.7447]
# Epoch:[1310/2000],data_loss:[0.7447]
# Epoch:[1311/2000],data_loss:[0.7447]
# Epoch:[1312/2000],data_loss:[0.7447]
# Epoch:[1313/2000],data_loss:[0.7447]
# Epoch:[1314/2000],data_loss:[0.7447]
# Epoch:[1315/2000],data_loss:[0.7447]
# Epoch:[1316/2000],data_loss:[0.7447]
# Epoch:[1317/2000],data_loss:[0.7447]
# Epoch:[1318/2000],data_loss:[0.7447]
# Epoch:[1319/2000],data_loss:[0.7447]
# Epoch:[1320/2000],data_loss:[0.7447]
# Epoch:[1321/2000],data_loss:[0.7447]
# Epoch:[1322/2000],data_loss:[0.7447]
# Epoch:[1323/2000],data_loss:[0.7447]
# Epoch:[1324/2000],data_loss:[0.7447]
# Epoch:[1325/2000],data_loss:[0.7447]
# Epoch:[1326/2000],data_loss:[0.7447]
# Epoch:[1327/2000],data_loss:[0.7447]
# ...
# Epoch:[1569/2000],data_loss:[0.7443]
# Epoch:[1570/2000],data_loss:[0.7443]
# Epoch:[1571/2000],data_loss:[0.7443]
# Epoch:[1572/2000],data_loss:[0.7443]
# Epoch:[1573/2000],data_loss:[0.7443]
# Epoch:[1574/2000],data_loss:[0.7443]
# Epoch:[1575/2000],data_loss:[0.7443]
# Epoch:[1576/2000],data_loss:[0.7443]
# Epoch:[1577/2000],data_loss:[0.7443]
# Epoch:[1578/2000],data_loss:[0.7443]
# Epoch:[1579/2000],data_loss:[0.7443]
# Epoch:[1580/2000],data_loss:[0.7443]
# Epoch:[1581/2000],data_loss:[0.7443]
# Epoch:[1582/2000],data_loss:[0.7443]
# Epoch:[1583/2000],data_loss:[0.7443]
# Epoch:[1584/2000],data_loss:[0.7443]
# Epoch:[1585/2000],data_loss:[0.7443]
# Epoch:[1586/2000],data_loss:[0.7443]
# Epoch:[1587/2000],data_loss:[0.7443]
# Epoch:[1588/2000],data_loss:[0.7443]
# Epoch:[1589/2000],data_loss:[0.7443]
# Epoch:[1590/2000],data_loss:[0.7443]
# Epoch:[1591/2000],data_loss:[0.7443]
# Epoch:[1592/2000],data_loss:[0.7443]
# Epoch:[1593/2000],data_loss:[0.7443]
# Epoch:[1594/2000],data_loss:[0.7443]
# Epoch:[1595/2000],data_loss:[0.7443]
# Epoch:[1596/2000],data_loss:[0.7443]
# Epoch:[1597/2000],data_loss:[0.7443]
# Epoch:[1598/2000],data_loss:[0.7443]
# Epoch:[1599/2000],data_loss:[0.7443]
# Epoch:[1600/2000],data_loss:[0.7443]
# Epoch:[1601/2000],data_loss:[0.7443]
# Epoch:[1602/2000],data_loss:[0.7443]
# Epoch:[1603/2000],data_loss:[0.7443]
# Epoch:[1604/2000],data_loss:[0.7443]
# Epoch:[1605/2000],data_loss:[0.7443]
# Epoch:[1606/2000],data_loss:[0.7443]
# Epoch:[1607/2000],data_loss:[0.7443]
# Epoch:[1608/2000],data_loss:[0.7443]
# Epoch:[1609/2000],data_loss:[0.7443]
# Epoch:[1610/2000],data_loss:[0.7443]
# Epoch:[1611/2000],data_loss:[0.7443]
# Epoch:[1612/2000],data_loss:[0.7443]
# Epoch:[1613/2000],data_loss:[0.7443]
# Epoch:[1614/2000],data_loss:[0.7443]
# Epoch:[1615/2000],data_loss:[0.7443]
# Epoch:[1616/2000],data_loss:[0.7443]
# Epoch:[1617/2000],data_loss:[0.7443]
# Epoch:[1618/2000],data_loss:[0.7443]
# Epoch:[1619/2000],data_loss:[0.7442]
# Epoch:[1620/2000],data_loss:[0.7442]
# Epoch:[1621/2000],data_loss:[0.7442]
# Epoch:[1622/2000],data_loss:[0.7442]
# Epoch:[1623/2000],data_loss:[0.7442]
# Epoch:[1624/2000],data_loss:[0.7442]
# Epoch:[1625/2000],data_loss:[0.7442]
# Epoch:[1626/2000],data_loss:[0.7442]
# Epoch:[1627/2000],data_loss:[0.7442]
# Epoch:[1628/2000],data_loss:[0.7442]
# Epoch:[1629/2000],data_loss:[0.7442]
# Epoch:[1630/2000],data_loss:[0.7442]
# Epoch:[1631/2000],data_loss:[0.7442]
# Epoch:[1632/2000],data_loss:[0.7442]
# Epoch:[1633/2000],data_loss:[0.7442]
# Epoch:[1634/2000],data_loss:[0.7442]
# Epoch:[1635/2000],data_loss:[0.7442]
# Epoch:[1636/2000],data_loss:[0.7442]
# Epoch:[1637/2000],data_loss:[0.7442]
# Epoch:[1638/2000],data_loss:[0.7442]
# Epoch:[1639/2000],data_loss:[0.7442]
# Epoch:[1640/2000],data_loss:[0.7442]
# Epoch:[1641/2000],data_loss:[0.7442]
# Epoch:[1642/2000],data_loss:[0.7442]
# Epoch:[1643/2000],data_loss:[0.7442]
# Epoch:[1644/2000],data_loss:[0.7442]
# Epoch:[1645/2000],data_loss:[0.7442]
# Epoch:[1646/2000],data_loss:[0.7442]
# Epoch:[1647/2000],data_loss:[0.7442]
# Epoch:[1648/2000],data_loss:[0.7442]
# Epoch:[1649/2000],data_loss:[0.7442]
# Epoch:[1650/2000],data_loss:[0.7442]
# Epoch:[1651/2000],data_loss:[0.7442]
# Epoch:[1652/2000],data_loss:[0.7442]
# Epoch:[1653/2000],data_loss:[0.7442]
# Epoch:[1654/2000],data_loss:[0.7442]
# Epoch:[1655/2000],data_loss:[0.7442]
# Epoch:[1656/2000],data_loss:[0.7442]
# Epoch:[1657/2000],data_loss:[0.7442]
# Epoch:[1658/2000],data_loss:[0.7442]
# Epoch:[1659/2000],data_loss:[0.7442]
# Epoch:[1660/2000],data_loss:[0.7442]
# Epoch:[1661/2000],data_loss:[0.7442]
# Epoch:[1662/2000],data_loss:[0.7442]
# Epoch:[1663/2000],data_loss:[0.7442]
# Epoch:[1664/2000],data_loss:[0.7442]
# Epoch:[1665/2000],data_loss:[0.7442]
# Epoch:[1666/2000],data_loss:[0.7442]
# Epoch:[1667/2000],data_loss:[0.7442]
# Epoch:[1668/2000],data_loss:[0.7442]
# Epoch:[1669/2000],data_loss:[0.7442]
# Epoch:[1670/2000],data_loss:[0.7442]
# Epoch:[1671/2000],data_loss:[0.7442]
# Epoch:[1672/2000],data_loss:[0.7442]
# Epoch:[1673/2000],data_loss:[0.7442]
# Epoch:[1674/2000],data_loss:[0.7442]
# Epoch:[1675/2000],data_loss:[0.7442]
# Epoch:[1676/2000],data_loss:[0.7442]
# Epoch:[1677/2000],data_loss:[0.7442]
# Epoch:[1678/2000],data_loss:[0.7442]
# Epoch:[1679/2000],data_loss:[0.7442]
# Epoch:[1680/2000],data_loss:[0.7442]
# Epoch:[1681/2000],data_loss:[0.7442]
# Epoch:[1682/2000],data_loss:[0.7442]
# Epoch:[1683/2000],data_loss:[0.7442]
# Epoch:[1684/2000],data_loss:[0.7442]
# Epoch:[1685/2000],data_loss:[0.7442]
# Epoch:[1686/2000],data_loss:[0.7442]
# Epoch:[1687/2000],data_loss:[0.7442]
# Epoch:[1688/2000],data_loss:[0.7442]
# Epoch:[1689/2000],data_loss:[0.7442]
# Epoch:[1690/2000],data_loss:[0.7442]
# Epoch:[1691/2000],data_loss:[0.7442]
# Epoch:[1692/2000],data_loss:[0.7442]
# Epoch:[1693/2000],data_loss:[0.7442]
# Epoch:[1694/2000],data_loss:[0.7442]
# Epoch:[1695/2000],data_loss:[0.7442]
# Epoch:[1696/2000],data_loss:[0.7442]
# Epoch:[1697/2000],data_loss:[0.7442]
# Epoch:[1698/2000],data_loss:[0.7442]
# Epoch:[1699/2000],data_loss:[0.7442]
# Epoch:[1700/2000],data_loss:[0.7442]
# Epoch:[1701/2000],data_loss:[0.7442]
# Epoch:[1702/2000],data_loss:[0.7442]
# Epoch:[1703/2000],data_loss:[0.7442]
# Epoch:[1704/2000],data_loss:[0.7442]
# Epoch:[1705/2000],data_loss:[0.7442]
# Epoch:[1706/2000],data_loss:[0.7442]
# Epoch:[1707/2000],data_loss:[0.7442]
# Epoch:[1708/2000],data_loss:[0.7442]
# Epoch:[1709/2000],data_loss:[0.7442]
# Epoch:[1710/2000],data_loss:[0.7442]
# Epoch:[1711/2000],data_loss:[0.7442]
# Epoch:[1712/2000],data_loss:[0.7442]
# Epoch:[1713/2000],data_loss:[0.7442]
# Epoch:[1714/2000],data_loss:[0.7442]
# Epoch:[1715/2000],data_loss:[0.7442]
# Epoch:[1716/2000],data_loss:[0.7442]
# Epoch:[1717/2000],data_loss:[0.7442]
# Epoch:[1718/2000],data_loss:[0.7442]
# Epoch:[1719/2000],data_loss:[0.7442]
# Epoch:[1720/2000],data_loss:[0.7441]
# Epoch:[1721/2000],data_loss:[0.7441]
# Epoch:[1722/2000],data_loss:[0.7441]
# Epoch:[1723/2000],data_loss:[0.7441]
# Epoch:[1724/2000],data_loss:[0.7441]
# Epoch:[1725/2000],data_loss:[0.7441]
# Epoch:[1726/2000],data_loss:[0.7441]
# Epoch:[1727/2000],data_loss:[0.7441]
# Epoch:[1728/2000],data_loss:[0.7441]
# Epoch:[1729/2000],data_loss:[0.7441]
# Epoch:[1730/2000],data_loss:[0.7441]
# Epoch:[1731/2000],data_loss:[0.7441]
# Epoch:[1732/2000],data_loss:[0.7441]
# Epoch:[1733/2000],data_loss:[0.7441]
# Epoch:[1734/2000],data_loss:[0.7441]
# Epoch:[1735/2000],data_loss:[0.7441]
# Epoch:[1736/2000],data_loss:[0.7441]
# Epoch:[1737/2000],data_loss:[0.7441]
# Epoch:[1738/2000],data_loss:[0.7441]
# Epoch:[1739/2000],data_loss:[0.7441]
# Epoch:[1740/2000],data_loss:[0.7441]
# Epoch:[1741/2000],data_loss:[0.7441]
# Epoch:[1742/2000],data_loss:[0.7441]
# Epoch:[1743/2000],data_loss:[0.7441]
# Epoch:[1744/2000],data_loss:[0.7441]
# Epoch:[1745/2000],data_loss:[0.7441]
# Epoch:[1746/2000],data_loss:[0.7441]
# Epoch:[1747/2000],data_loss:[0.7441]
# Epoch:[1748/2000],data_loss:[0.7441]
# Epoch:[1749/2000],data_loss:[0.7441]
# Epoch:[1750/2000],data_loss:[0.7441]
# Epoch:[1751/2000],data_loss:[0.7441]
# Epoch:[1752/2000],data_loss:[0.7441]
# Epoch:[1753/2000],data_loss:[0.7441]
# Epoch:[1754/2000],data_loss:[0.7441]
# Epoch:[1755/2000],data_loss:[0.7441]
# Epoch:[1756/2000],data_loss:[0.7441]
# Epoch:[1757/2000],data_loss:[0.7441]
# Epoch:[1758/2000],data_loss:[0.7441]
# Epoch:[1759/2000],data_loss:[0.7441]
# Epoch:[1760/2000],data_loss:[0.7441]
# Epoch:[1761/2000],data_loss:[0.7441]
# Epoch:[1762/2000],data_loss:[0.7441]
# Epoch:[1763/2000],data_loss:[0.7441]
# Epoch:[1764/2000],data_loss:[0.7441]
# Epoch:[1765/2000],data_loss:[0.7441]
# Epoch:[1766/2000],data_loss:[0.7441]
# Epoch:[1767/2000],data_loss:[0.7441]
# Epoch:[1768/2000],data_loss:[0.7441]
# Epoch:[1769/2000],data_loss:[0.7441]
# Epoch:[1770/2000],data_loss:[0.7441]
# Epoch:[1771/2000],data_loss:[0.7441]
# Epoch:[1772/2000],data_loss:[0.7441]
# Epoch:[1773/2000],data_loss:[0.7441]
# Epoch:[1774/2000],data_loss:[0.7441]
# Epoch:[1775/2000],data_loss:[0.7441]
# Epoch:[1776/2000],data_loss:[0.7441]
# Epoch:[1777/2000],data_loss:[0.7441]
# Epoch:[1778/2000],data_loss:[0.7441]
# Epoch:[1779/2000],data_loss:[0.7441]
# Epoch:[1780/2000],data_loss:[0.7441]
# Epoch:[1781/2000],data_loss:[0.7441]
# Epoch:[1782/2000],data_loss:[0.7441]
# Epoch:[1783/2000],data_loss:[0.7441]
# Epoch:[1784/2000],data_loss:[0.7441]
# Epoch:[1785/2000],data_loss:[0.7441]
# Epoch:[1786/2000],data_loss:[0.7441]
# Epoch:[1787/2000],data_loss:[0.7441]
# Epoch:[1788/2000],data_loss:[0.7441]
# Epoch:[1789/2000],data_loss:[0.7441]
# Epoch:[1790/2000],data_loss:[0.7441]
# Epoch:[1791/2000],data_loss:[0.7441]
# Epoch:[1792/2000],data_loss:[0.7441]
# Epoch:[1793/2000],data_loss:[0.7441]
# Epoch:[1794/2000],data_loss:[0.7441]
# Epoch:[1795/2000],data_loss:[0.7441]
# Epoch:[1796/2000],data_loss:[0.7441]
# Epoch:[1797/2000],data_loss:[0.7441]
# Epoch:[1798/2000],data_loss:[0.7441]
# Epoch:[1799/2000],data_loss:[0.7441]
# Epoch:[1800/2000],data_loss:[0.7441]
# Epoch:[1801/2000],data_loss:[0.7441]
# Epoch:[1802/2000],data_loss:[0.7441]
# Epoch:[1803/2000],data_loss:[0.7441]
# Epoch:[1804/2000],data_loss:[0.7441]
# Epoch:[1805/2000],data_loss:[0.7441]
# Epoch:[1806/2000],data_loss:[0.7441]
# Epoch:[1807/2000],data_loss:[0.7441]
# Epoch:[1808/2000],data_loss:[0.7441]
# Epoch:[1809/2000],data_loss:[0.7441]
# Epoch:[1810/2000],data_loss:[0.7441]
# Epoch:[1811/2000],data_loss:[0.7441]
# Epoch:[1812/2000],data_loss:[0.7441]
# Epoch:[1813/2000],data_loss:[0.7441]
# Epoch:[1814/2000],data_loss:[0.7441]
# Epoch:[1815/2000],data_loss:[0.7441]
# Epoch:[1816/2000],data_loss:[0.7441]
# Epoch:[1817/2000],data_loss:[0.7441]
# Epoch:[1818/2000],data_loss:[0.7441]
# Epoch:[1819/2000],data_loss:[0.7441]
# Epoch:[1820/2000],data_loss:[0.7441]
# Epoch:[1821/2000],data_loss:[0.7441]
# Epoch:[1822/2000],data_loss:[0.7441]
# Epoch:[1823/2000],data_loss:[0.7441]
# Epoch:[1824/2000],data_loss:[0.7441]
# Epoch:[1825/2000],data_loss:[0.7441]
# Epoch:[1826/2000],data_loss:[0.7441]
# Epoch:[1827/2000],data_loss:[0.7441]
# Epoch:[1828/2000],data_loss:[0.7441]
# Epoch:[1829/2000],data_loss:[0.7441]
# Epoch:[1830/2000],data_loss:[0.7441]
# Epoch:[1831/2000],data_loss:[0.7441]
# Epoch:[1832/2000],data_loss:[0.7441]
# Epoch:[1833/2000],data_loss:[0.7441]
# Epoch:[1834/2000],data_loss:[0.7441]
# Epoch:[1835/2000],data_loss:[0.7441]
# Epoch:[1836/2000],data_loss:[0.7441]
# Epoch:[1837/2000],data_loss:[0.7441]
# Epoch:[1838/2000],data_loss:[0.7440]
# Epoch:[1839/2000],data_loss:[0.7440]
# Epoch:[1840/2000],data_loss:[0.7440]
# Epoch:[1841/2000],data_loss:[0.7440]
# Epoch:[1842/2000],data_loss:[0.7440]
# Epoch:[1843/2000],data_loss:[0.7440]
# Epoch:[1844/2000],data_loss:[0.7440]
# Epoch:[1845/2000],data_loss:[0.7440]
# Epoch:[1846/2000],data_loss:[0.7440]
# Epoch:[1847/2000],data_loss:[0.7440]
# Epoch:[1848/2000],data_loss:[0.7440]
# Epoch:[1849/2000],data_loss:[0.7440]
# Epoch:[1850/2000],data_loss:[0.7440]
# Epoch:[1851/2000],data_loss:[0.7440]
# Epoch:[1852/2000],data_loss:[0.7440]
# Epoch:[1853/2000],data_loss:[0.7440]
# Epoch:[1854/2000],data_loss:[0.7440]
# Epoch:[1855/2000],data_loss:[0.7440]
# Epoch:[1856/2000],data_loss:[0.7440]
# Epoch:[1857/2000],data_loss:[0.7440]
# Epoch:[1858/2000],data_loss:[0.7440]
# Epoch:[1859/2000],data_loss:[0.7440]
# Epoch:[1860/2000],data_loss:[0.7440]
# Epoch:[1861/2000],data_loss:[0.7440]
# Epoch:[1862/2000],data_loss:[0.7440]
# Epoch:[1863/2000],data_loss:[0.7440]
# Epoch:[1864/2000],data_loss:[0.7440]
# Epoch:[1865/2000],data_loss:[0.7440]
# Epoch:[1866/2000],data_loss:[0.7440]
# Epoch:[1867/2000],data_loss:[0.7440]
# Epoch:[1868/2000],data_loss:[0.7440]
# Epoch:[1869/2000],data_loss:[0.7440]
# Epoch:[1870/2000],data_loss:[0.7440]
# Epoch:[1871/2000],data_loss:[0.7440]
# Epoch:[1872/2000],data_loss:[0.7440]
# Epoch:[1873/2000],data_loss:[0.7440]
# Epoch:[1874/2000],data_loss:[0.7440]
# Epoch:[1875/2000],data_loss:[0.7440]
# Epoch:[1876/2000],data_loss:[0.7440]
# Epoch:[1877/2000],data_loss:[0.7440]
# Epoch:[1878/2000],data_loss:[0.7440]
# Epoch:[1879/2000],data_loss:[0.7440]
# Epoch:[1880/2000],data_loss:[0.7440]
# Epoch:[1881/2000],data_loss:[0.7440]
# Epoch:[1882/2000],data_loss:[0.7440]
# Epoch:[1883/2000],data_loss:[0.7440]
# Epoch:[1884/2000],data_loss:[0.7440]
# Epoch:[1885/2000],data_loss:[0.7440]
# Epoch:[1886/2000],data_loss:[0.7440]
# Epoch:[1887/2000],data_loss:[0.7440]
# Epoch:[1888/2000],data_loss:[0.7440]
# Epoch:[1889/2000],data_loss:[0.7440]
# Epoch:[1890/2000],data_loss:[0.7440]
# Epoch:[1891/2000],data_loss:[0.7440]
# Epoch:[1892/2000],data_loss:[0.7440]
# Epoch:[1893/2000],data_loss:[0.7440]
# Epoch:[1894/2000],data_loss:[0.7440]
# Epoch:[1895/2000],data_loss:[0.7440]
# Epoch:[1896/2000],data_loss:[0.7440]
# Epoch:[1897/2000],data_loss:[0.7440]
# Epoch:[1898/2000],data_loss:[0.7440]
# Epoch:[1899/2000],data_loss:[0.7440]
# Epoch:[1900/2000],data_loss:[0.7440]
# Epoch:[1901/2000],data_loss:[0.7440]
# Epoch:[1902/2000],data_loss:[0.7440]
# Epoch:[1903/2000],data_loss:[0.7440]
# Epoch:[1904/2000],data_loss:[0.7440]
# Epoch:[1905/2000],data_loss:[0.7440]
# Epoch:[1906/2000],data_loss:[0.7440]
# Epoch:[1907/2000],data_loss:[0.7440]
# Epoch:[1908/2000],data_loss:[0.7440]
# Epoch:[1909/2000],data_loss:[0.7440]
# Epoch:[1910/2000],data_loss:[0.7440]
# Epoch:[1911/2000],data_loss:[0.7440]
# Epoch:[1912/2000],data_loss:[0.7440]
# Epoch:[1913/2000],data_loss:[0.7440]
# Epoch:[1914/2000],data_loss:[0.7440]
# Epoch:[1915/2000],data_loss:[0.7440]
# Epoch:[1916/2000],data_loss:[0.7440]
# Epoch:[1917/2000],data_loss:[0.7440]
# Epoch:[1918/2000],data_loss:[0.7440]
# Epoch:[1919/2000],data_loss:[0.7440]
# Epoch:[1920/2000],data_loss:[0.7440]
# Epoch:[1921/2000],data_loss:[0.7440]
# Epoch:[1922/2000],data_loss:[0.7440]
# Epoch:[1923/2000],data_loss:[0.7440]
# Epoch:[1924/2000],data_loss:[0.7440]
# Epoch:[1925/2000],data_loss:[0.7440]
# Epoch:[1926/2000],data_loss:[0.7440]
# Epoch:[1927/2000],data_loss:[0.7440]
# Epoch:[1928/2000],data_loss:[0.7440]
# Epoch:[1929/2000],data_loss:[0.7440]
# Epoch:[1930/2000],data_loss:[0.7440]
# Epoch:[1931/2000],data_loss:[0.7440]
# Epoch:[1932/2000],data_loss:[0.7440]
# Epoch:[1933/2000],data_loss:[0.7440]
# Epoch:[1934/2000],data_loss:[0.7440]
# Epoch:[1935/2000],data_loss:[0.7440]
# Epoch:[1936/2000],data_loss:[0.7440]
# Epoch:[1937/2000],data_loss:[0.7440]
# Epoch:[1938/2000],data_loss:[0.7440]
# Epoch:[1939/2000],data_loss:[0.7440]
# Epoch:[1940/2000],data_loss:[0.7440]
# Epoch:[1941/2000],data_loss:[0.7440]
# Epoch:[1942/2000],data_loss:[0.7440]
# Epoch:[1943/2000],data_loss:[0.7440]
# Epoch:[1944/2000],data_loss:[0.7440]
# Epoch:[1945/2000],data_loss:[0.7440]
# Epoch:[1946/2000],data_loss:[0.7440]
# Epoch:[1947/2000],data_loss:[0.7440]
# Epoch:[1948/2000],data_loss:[0.7440]
# Epoch:[1949/2000],data_loss:[0.7440]
# Epoch:[1950/2000],data_loss:[0.7440]
# Epoch:[1951/2000],data_loss:[0.7440]
# Epoch:[1952/2000],data_loss:[0.7440]
# Epoch:[1953/2000],data_loss:[0.7440]
# Epoch:[1954/2000],data_loss:[0.7440]
# Epoch:[1955/2000],data_loss:[0.7440]
# Epoch:[1956/2000],data_loss:[0.7440]
# Epoch:[1957/2000],data_loss:[0.7440]
# Epoch:[1958/2000],data_loss:[0.7440]
# Epoch:[1959/2000],data_loss:[0.7440]
# Epoch:[1960/2000],data_loss:[0.7440]
# Epoch:[1961/2000],data_loss:[0.7440]
# Epoch:[1962/2000],data_loss:[0.7440]
# Epoch:[1963/2000],data_loss:[0.7440]
# Epoch:[1964/2000],data_loss:[0.7440]
# Epoch:[1965/2000],data_loss:[0.7440]
# Epoch:[1966/2000],data_loss:[0.7440]
# Epoch:[1967/2000],data_loss:[0.7440]
# Epoch:[1968/2000],data_loss:[0.7440]
# Epoch:[1969/2000],data_loss:[0.7440]
# Epoch:[1970/2000],data_loss:[0.7440]
# Epoch:[1971/2000],data_loss:[0.7440]
# Epoch:[1972/2000],data_loss:[0.7440]
# Epoch:[1973/2000],data_loss:[0.7440]
# Epoch:[1974/2000],data_loss:[0.7440]
# Epoch:[1975/2000],data_loss:[0.7440]
# Epoch:[1976/2000],data_loss:[0.7439]
# Epoch:[1977/2000],data_loss:[0.7439]
# Epoch:[1978/2000],data_loss:[0.7439]
# Epoch:[1979/2000],data_loss:[0.7439]
# Epoch:[1980/2000],data_loss:[0.7439]
# Epoch:[1981/2000],data_loss:[0.7439]
# Epoch:[1982/2000],data_loss:[0.7439]
# Epoch:[1983/2000],data_loss:[0.7439]
# Epoch:[1984/2000],data_loss:[0.7439]
# Epoch:[1985/2000],data_loss:[0.7439]
# Epoch:[1986/2000],data_loss:[0.7439]
# Epoch:[1987/2000],data_loss:[0.7439]
# Epoch:[1988/2000],data_loss:[0.7439]
# Epoch:[1989/2000],data_loss:[0.7439]
# Epoch:[1990/2000],data_loss:[0.7439]
# Epoch:[1991/2000],data_loss:[0.7439]
# Epoch:[1992/2000],data_loss:[0.7439]
# Epoch:[1993/2000],data_loss:[0.7439]
# Epoch:[1994/2000],data_loss:[0.7439]
# Epoch:[1995/2000],data_loss:[0.7439]
# Epoch:[1996/2000],data_loss:[0.7439]
# Epoch:[1997/2000],data_loss:[0.7439]
# Epoch:[1998/2000],data_loss:[0.7439]
# Epoch:[1999/2000],data_loss:[0.7439]
# Epoch:[2000/2000],data_loss:[0.7439]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(range(len(loss_data_train)),loss_data_train,c="blue",label= "train_data")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(range(len(loss_data_val)),loss_data_val,c="red",label= "val_data")
plt.legend()
plt.show()

# %%
y_val = net(X_val_tensor.unsqueeze(1))

# %%
y_val = y_val.squeeze().detach().numpy()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(range(len(Y_val)),Y_val,c="blue",label= "Data")
plt.plot(range(len(y_val)),y_val,c="red",label = "Predict")
plt.legend()
plt.show()

# %%
y_val.shape
# Out:
# (480,)

# %%
path = './val_data_60.csv'

# %%
pd_test = pd.read_csv(path, encoding='gbk')

# %%
X_test = pd_test[['mean',  'sd', 'min', 'max', '10th', '25th', '50th', '75th','90th']]
Y_test = pd_test[['MET']]
X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
X_test = scaler.transform(X_test)

# %%
X_test_tensor = torch.from_numpy(X_test).float() 
Y_test_tensor = torch.from_numpy(Y_test).float()

# %%
test_data = X_test_tensor.unsqueeze(1)
output_predict = net(test_data)

# %%
output_predict = output_predict.squeeze().detach().numpy()

# %%
pd_test['model_pred'] = output_predict

# %%
pd_test.to_csv('val_model_pred.csv')

# %%
y_val_array = []
for item in y_val:
    y_val_array.append(item)

Y_val_array = []
for item in Y_val:
    Y_val_array.append(float(item))   
    
    
m=MSE(Y_val_array,y_val_array)     
r = stats.pearsonr(y_val_array,Y_val_array) 
t=time.strftime("%Y-%m-%d %H:%M:%S",time.localtime())
NN_struct="{0}、{1}、{2}".format(d1,d2,d3)
print (m)
print (r)
print (NN_struct)

path='performance.csv'
csvfile= open(path, 'a', newline='') 
if os.path.getsize(path)!=0:
    writer = csv.writer(csvfile)
    row=[t,freq,NN_struct,str(m),str(r)]  
    writer.writerow(row)
    csvfile.close()  
else:
    writer = csv.writer(csvfile)
    row0 = [u'time', u'frequency（s）', u'structure', u'MSE', u'pearson']  
    writer.writerow(row0)
    row=[t,freq,NN_struct,str(m),str(r)]  
    writer.writerow(row)
    csvfile.close()
# Out:
# 0.8158695476703729
# (0.9349455321497474, 3.007087825475138e-217)
# 9、8、1
